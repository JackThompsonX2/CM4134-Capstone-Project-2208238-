# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow import keras
import warnings


warnings.filterwarnings('ignore')



model= keras.models.load_model("Classifiaction_model_full_multi.keras")
img_size = 128
dataset = os.listdir("music_dataset_spectro_full_single/train") #use as labels
labels = dataset
print(labels)
# Out:
# ['Accordion', 'Acoustic_Guitar', 'Banjo', 'Bass_Guitar', 'Clarinet', 'cowbell', 'Dobro', 'Drum_set', 'Electric_Guitar', 'flute', 'Harmonium', 'Horn', 'Keyboard', 'Mandolin', 'Organ', 'Piano', 'Saxophone', 'Shakers', 'Tambourine', 'Trombone', 'Trumpet', 'Ukulele', 'vibraphone', 'Violin']

# %%
#Accordion test
img = cv2.imread("music_dataset_spectro_full_single/test/Accordion/2864_Accordion.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

labels=np.array(labels)
pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# ['Organ']

# %%
#acoustic guitar test
img = cv2.imread("music_dataset_spectro_full_single/test/Acoustic_Guitar/2923_Acoustic_Guitar.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Organ']

# %%
#Banjo test
img = cv2.imread("music_dataset_spectro_full_single/test/Banjo/2398_Banjo.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Organ']

# %%
#Bass_Guitar test
img = cv2.imread("music_dataset_spectro_full_single/test/Bass_Guitar/2890_Bass_Guitar.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ['Organ']

# %%
#Clarinet test
img = cv2.imread("music_dataset_spectro_full_single/test/Clarinet/507_Clarinet.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Organ']

# %%
#cowbell test
img = cv2.imread("music_dataset_spectro_full_single/test/cowbell/496_cowbell.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ['Organ']

# %%
#Dobro test
img = cv2.imread("music_dataset_spectro_full_single/test/Dobro/389_Dobro.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Organ']

# %%
#Drum_set test
img = cv2.imread("music_dataset_spectro_full_single/test/Drum_set/2918_Drum_set.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Organ']

# %%
#Electric_Guitar test
img = cv2.imread("music_dataset_spectro_full_single/test/Electric_Guitar/1052_Electric_Guitar.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Organ']

# %%
#Flute test
img = cv2.imread("music_dataset_spectro_full_single/test/flute/2975_flute.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ['Organ']

# %%
#Harmonium test
img = cv2.imread("music_dataset_spectro_full_single/test/Harmonium/1051_Harmonium.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ['Organ']

# %%
#Horn test
img = cv2.imread("music_dataset_spectro_full_single/test/Horn/1006_Horn.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Violin']

# %%
#Keyboard test
img = cv2.imread("music_dataset_spectro_full_single/test/Keyboard/1632_Keyboard.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ['Organ']

# %%
#Mandolin test
img = cv2.imread("music_dataset_spectro_full_single/test/Mandolin/1966_Mandolin.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ['Organ']

# %%
#Organ test
img = cv2.imread("music_dataset_spectro_full_single/test/Organ/1153_Organ.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Organ']

# %%
#Piano test
img = cv2.imread("music_dataset_spectro_full_single/test/Piano/460_Piano.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ['Organ']

# %%
#Saxophone test
img = cv2.imread("music_dataset_spectro_full_single/test/Saxophone/363_Saxophone.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Organ']

# %%
#Shakers test
img = cv2.imread("music_dataset_spectro_full_single/test/Shakers/1085_Shakers.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Organ']

# %%
#Tambourine test
img = cv2.imread("music_dataset_spectro_full_single/test/Tambourine/446_Tambourine.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Organ']

# %%
#Trombone test
img = cv2.imread("music_dataset_spectro_full_single/test/Trombone/2372_Trombone.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ['Organ']

# %%
#trumpet test
img = cv2.imread("music_dataset_spectro_full_single/test/Trumpet/402_Trumpet.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ['Organ']

# %%
#Ukulele test
img = cv2.imread("music_dataset_spectro_full_single/test/Ukulele/632_Ukulele.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Violin']

# %%
#vibraphone test
img = cv2.imread("music_dataset_spectro_full_single/test/vibraphone/404_vibraphone.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Organ']

# %%
#violin test
img = cv2.imread("music_dataset_spectro_full_single/test/Violin/504_Violin.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Organ']

# %%
# 32836 accordian, keyboard, trombone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32836_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.09739322 0.10387162 0.09694903 0.10022099 0.10093796 0.09348806
#   0.10065683 0.09759429 0.10458533 0.09822105 0.10772406 0.09831454
#   0.09560847 0.09637304 0.11033848 0.10162962 0.10071411 0.10139136
#   0.10126057 0.10233712 0.10564472 0.10194691 0.09971515 0.10841563]]
# [['Organ' 'Violin' 'Harmonium' 'Trumpet' 'Electric_Guitar'
#   'Acoustic_Guitar' 'Trombone' 'Ukulele' 'Piano' 'Shakers' 'Tambourine'
#   'Clarinet' 'Saxophone' 'Dobro' 'Bass_Guitar' 'vibraphone' 'Horn'
#   'flute' 'Drum_set' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Violin' 'Harmonium']

# %%
# 32837 Mandolin, trombone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32837_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top2 = [prediction2[0][0],prediction2[0][1]]

print(labels[prediction2])
print(labels[top2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[0.10043228 0.10613065 0.0998437  0.10239022 0.10468342 0.0953328
#   0.10360906 0.10187504 0.10865998 0.10235361 0.11134284 0.10224597
#   0.09835802 0.09849478 0.11384472 0.10431638 0.10435501 0.10482943
#   0.10419921 0.10660175 0.10871675 0.10598197 0.10222258 0.11215853]]
# [['Organ' 'Violin' 'Harmonium' 'Trumpet' 'Electric_Guitar' 'Trombone'
#   'Acoustic_Guitar' 'Ukulele' 'Shakers' 'Clarinet' 'Saxophone' 'Piano'
#   'Tambourine' 'Dobro' 'Bass_Guitar' 'flute' 'Horn' 'vibraphone'
#   'Drum_set' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Violin']

# %%
# 32838 banjo, bass_guitar Piano

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32838_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [[0.10118839 0.10778327 0.10105398 0.10448676 0.10475718 0.09689147
#   0.10325631 0.10063846 0.10702996 0.10123562 0.11117744 0.10027363
#   0.09942017 0.09972149 0.11285418 0.10461522 0.10443069 0.10471737
#   0.10317324 0.10521397 0.10732559 0.10536034 0.10214558 0.11065025]]
# [['Organ' 'Harmonium' 'Violin' 'Acoustic_Guitar' 'Trumpet'
#   'Electric_Guitar' 'Ukulele' 'Trombone' 'Clarinet' 'Shakers' 'Piano'
#   'Bass_Guitar' 'Saxophone' 'Dobro' 'Tambourine' 'vibraphone' 'flute'
#   'Accordion' 'Banjo' 'Drum_set' 'Horn' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Harmonium' 'Violin']

# %%
# 32839 keyboard, organ, Piano

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32839_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[0.09888398 0.10533054 0.09903625 0.10104693 0.10259146 0.09568485
#   0.10230512 0.09976583 0.10621928 0.10076167 0.10963279 0.10068269
#   0.09704407 0.0979377  0.11210211 0.10428114 0.10163947 0.10304305
#   0.10300337 0.10485529 0.10830087 0.10307884 0.10191456 0.10963082]]
# [['Organ' 'Harmonium' 'Violin' 'Trumpet' 'Electric_Guitar'
#   'Acoustic_Guitar' 'Trombone' 'Piano' 'Ukulele' 'Shakers' 'Tambourine'
#   'Clarinet' 'Dobro' 'vibraphone' 'Saxophone' 'Bass_Guitar' 'flute'
#   'Horn' 'Drum_set' 'Banjo' 'Accordion' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Harmonium' 'Violin']

# %%
# 32840 acoustic guitar, banjo, violin

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32840_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.09996669 0.10631382 0.09984316 0.10208156 0.1045369  0.09584867
#   0.1040182  0.10151354 0.10828291 0.10191668 0.11115457 0.10250192
#   0.09799598 0.0988037  0.11384082 0.10525575 0.10397585 0.10421813
#   0.104781   0.10627861 0.10897542 0.10546048 0.1028597  0.1122422 ]]
# [['Organ' 'Violin' 'Harmonium' 'Trumpet' 'Electric_Guitar'
#   'Acoustic_Guitar' 'Trombone' 'Ukulele' 'Piano' 'Tambourine' 'Clarinet'
#   'Shakers' 'Dobro' 'Saxophone' 'vibraphone' 'Horn' 'Bass_Guitar' 'flute'
#   'Drum_set' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Violin' 'Harmonium']

# %%
# 32841 acoustic guitar, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32841_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top2 = [prediction2[0][0],prediction2[0][1]]

print(labels[prediction2])
print(labels[top2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[0.10345235 0.10874383 0.10226436 0.10451481 0.10606621 0.09756772
#   0.10553335 0.10435499 0.10994789 0.1043245  0.11299934 0.10414151
#   0.10035236 0.10087367 0.11578334 0.10668609 0.1051072  0.10730939
#   0.10530728 0.1086627  0.11056277 0.10691813 0.10464618 0.11305007]]
# [['Organ' 'Violin' 'Harmonium' 'Trumpet' 'Electric_Guitar'
#   'Acoustic_Guitar' 'Trombone' 'Shakers' 'Ukulele' 'Piano' 'Clarinet'
#   'Dobro' 'Tambourine' 'Saxophone' 'vibraphone' 'Bass_Guitar' 'Drum_set'
#   'flute' 'Horn' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Violin']

# %%
# 32842 acoustic guitar, cowbell,horn

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32841_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[0.10345235 0.10874383 0.10226436 0.10451481 0.10606621 0.09756772
#   0.10553335 0.10435499 0.10994789 0.1043245  0.11299934 0.10414151
#   0.10035236 0.10087367 0.11578334 0.10668609 0.1051072  0.10730939
#   0.10530728 0.1086627  0.11056277 0.10691813 0.10464618 0.11305007]]
# [['Organ' 'Violin' 'Harmonium' 'Trumpet' 'Electric_Guitar'
#   'Acoustic_Guitar' 'Trombone' 'Shakers' 'Ukulele' 'Piano' 'Clarinet'
#   'Dobro' 'Tambourine' 'Saxophone' 'vibraphone' 'Bass_Guitar' 'Drum_set'
#   'flute' 'Horn' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Violin' 'Harmonium']

# %%
# 32843 drum_set, flute,shakers

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32843_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.09899175 0.10552338 0.09860709 0.10223358 0.10307916 0.09522162
#   0.10307452 0.0996444  0.10668512 0.10083964 0.11018582 0.10056423
#   0.09753582 0.09723426 0.11236805 0.10344795 0.10356866 0.10319155
#   0.10337423 0.10539803 0.10729862 0.10422693 0.10119827 0.11007966]]
# [['Organ' 'Harmonium' 'Violin' 'Trumpet' 'Electric_Guitar'
#   'Acoustic_Guitar' 'Trombone' 'Ukulele' 'Saxophone' 'Piano' 'Tambourine'
#   'Shakers' 'Clarinet' 'Dobro' 'Bass_Guitar' 'vibraphone' 'flute' 'Horn'
#   'Drum_set' 'Accordion' 'Banjo' 'Keyboard' 'Mandolin' 'cowbell']]
# ['Organ' 'Harmonium' 'Violin']

# %%
# 32845 acoustic guitar, dobro,trombone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32845_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.10081904 0.10718692 0.10029789 0.10321328 0.10457237 0.09629051
#   0.10311973 0.10128796 0.10792156 0.10183163 0.11123513 0.10132544
#   0.09894329 0.09929775 0.1136321  0.10469743 0.10408219 0.10491093
#   0.10363846 0.1059758  0.10815427 0.10563599 0.10251591 0.11110911]]
# [['Organ' 'Harmonium' 'Violin' 'Trumpet' 'Electric_Guitar'
#   'Acoustic_Guitar' 'Trombone' 'Ukulele' 'Shakers' 'Piano' 'Clarinet'
#   'Saxophone' 'Tambourine' 'Bass_Guitar' 'Dobro' 'vibraphone' 'flute'
#   'Horn' 'Drum_set' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Harmonium' 'Violin']

# %%
# 32846 bass guitar, harmonium, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32846_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.09831478 0.10462726 0.09794012 0.10032442 0.10330265 0.09484509
#   0.10326523 0.1009457  0.10822015 0.10186013 0.11045652 0.1025522
#   0.09714035 0.09714571 0.11410024 0.10463138 0.10311182 0.10361779
#   0.10444631 0.10633224 0.10917513 0.10495942 0.10252583 0.1115112 ]]
# [['Organ' 'Violin' 'Harmonium' 'Trumpet' 'Electric_Guitar' 'Trombone'
#   'Ukulele' 'Piano' 'Acoustic_Guitar' 'Tambourine' 'Shakers' 'Clarinet'
#   'Dobro' 'Saxophone' 'Horn' 'vibraphone' 'flute' 'Drum_set'
#   'Bass_Guitar' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Violin' 'Harmonium']

# %%
# 32849 tambourine, violin

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32849_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top2 = [prediction2[0][0],prediction2[0][1]]

print(labels[prediction2])
print(labels[top2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.10459772 0.10995722 0.10448151 0.1073613  0.11002127 0.09946241
#   0.10937525 0.10585639 0.11251444 0.1060618  0.11581047 0.10665272
#   0.10214335 0.10240959 0.11794975 0.10950005 0.10932552 0.10793924
#   0.10873232 0.11057749 0.11222733 0.11050887 0.10643303 0.11773703]]
# [['Organ' 'Violin' 'Harmonium' 'Electric_Guitar' 'Trumpet' 'Trombone'
#   'Ukulele' 'Clarinet' 'Acoustic_Guitar' 'Piano' 'Dobro' 'Saxophone'
#   'Tambourine' 'Shakers' 'Bass_Guitar' 'Horn' 'vibraphone' 'flute'
#   'Drum_set' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Violin']

# %%
# 32860 saxophone, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32860_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top2 = [prediction2[0][0],prediction2[0][1]]

print(labels[prediction2])
print(labels[top2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.10284968 0.10869358 0.1030169  0.10685413 0.10690747 0.09768916
#   0.10578062 0.10157672 0.10776086 0.10167501 0.11291283 0.10194875
#   0.09990418 0.10081233 0.11359049 0.10514209 0.10654335 0.10585232
#   0.10508824 0.10632944 0.1085734  0.1065973  0.10300072 0.11392036]]
# [['Violin' 'Organ' 'Harmonium' 'Acoustic_Guitar' 'Trumpet'
#   'Electric_Guitar' 'Clarinet' 'Bass_Guitar' 'Ukulele' 'Saxophone'
#   'Trombone' 'Shakers' 'Dobro' 'Piano' 'Tambourine' 'Banjo' 'vibraphone'
#   'Accordion' 'Horn' 'flute' 'Drum_set' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Violin' 'Organ']

# %%
# 32872 eletric guitar, mandolin, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32872_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[0.0962856  0.10240979 0.09562494 0.09779721 0.09933683 0.09143456
#   0.09737176 0.09675037 0.10307491 0.09722022 0.1059608  0.09677093
#   0.09391289 0.0946591  0.10848037 0.09944963 0.09834982 0.10043442
#   0.0983911  0.10116469 0.10345505 0.10063925 0.09769805 0.10568507]]
# [['Organ' 'Harmonium' 'Violin' 'Trumpet' 'Electric_Guitar'
#   'Acoustic_Guitar' 'Trombone' 'Ukulele' 'Shakers' 'Piano' 'Clarinet'
#   'Tambourine' 'Saxophone' 'Bass_Guitar' 'vibraphone' 'Dobro' 'flute'
#   'Horn' 'Drum_set' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Harmonium' 'Violin']

# %%
# 32866 banjo, clarinet, violin

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32866_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[0.09980252 0.10526783 0.09961659 0.100717   0.10471296 0.09438481
#   0.10306612 0.10260572 0.10872591 0.10281879 0.11138208 0.10296059
#   0.09761146 0.09787632 0.1137173  0.10464452 0.10377412 0.10449053
#   0.10393816 0.10712217 0.10860249 0.10598199 0.10223788 0.11190686]]
# [['Organ' 'Violin' 'Harmonium' 'Electric_Guitar' 'Trumpet' 'Trombone'
#   'Ukulele' 'Acoustic_Guitar' 'Clarinet' 'Piano' 'Shakers' 'Tambourine'
#   'Saxophone' 'Dobro' 'Horn' 'flute' 'Drum_set' 'vibraphone'
#   'Bass_Guitar' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Violin' 'Harmonium']

# %%
# 32861 ukulele, cowbell, acoustic guitar
img = cv2.imread("Music_mixes_dataset_classification/test/mix/32861_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.10221304 0.10859042 0.10192807 0.10497563 0.10733452 0.09888139
#   0.10739534 0.10389794 0.11086944 0.10469582 0.113922   0.10511758
#   0.10093613 0.10125584 0.11708906 0.10820368 0.10704701 0.10660452
#   0.10765446 0.10857773 0.11172799 0.10815369 0.10588534 0.11512955]]
# [['Organ' 'Violin' 'Harmonium' 'Trumpet' 'Electric_Guitar'
#   'Acoustic_Guitar' 'Trombone' 'Piano' 'Ukulele' 'Tambourine' 'Dobro'
#   'Clarinet' 'Saxophone' 'Shakers' 'vibraphone' 'Horn' 'Bass_Guitar'
#   'flute' 'Drum_set' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Violin' 'Harmonium']

# %%
# 32862 saxophone, trumpet,

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32862_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top2 = [prediction2[0][0],prediction2[0][1]]

print(labels[prediction2])
print(labels[top2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.10343986 0.1086858  0.10317441 0.10566002 0.10801584 0.09776635
#   0.10727891 0.10412851 0.1104173  0.10406122 0.11390559 0.10473649
#   0.10057392 0.10155173 0.11612873 0.1074468  0.10720725 0.10652063
#   0.10682803 0.10820501 0.11054549 0.10830983 0.10489867 0.11577146]]
# [['Organ' 'Violin' 'Harmonium' 'Trumpet' 'Electric_Guitar'
#   'Acoustic_Guitar' 'Ukulele' 'Trombone' 'Clarinet' 'Piano' 'Dobro'
#   'Saxophone' 'Tambourine' 'Shakers' 'Bass_Guitar' 'vibraphone' 'Horn'
#   'Drum_set' 'flute' 'Accordion' 'Banjo' 'Mandolin' 'Keyboard' 'cowbell']]
# ['Organ' 'Violin']
