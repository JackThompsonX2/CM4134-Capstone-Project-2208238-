# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.image import imread
from PIL import Image
import tensorflow as tf
np.random.seed(1337)
import gc

from tensorflow.keras import layers
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, AveragePooling2D,Flatten, Dense, Conv2D,MaxPool2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')


img_size = 128
print(os.listdir())
dataset = os.listdir("music_dataset_spectro_full/train")
labels = dataset
print(labels)
# Out:
# ['.git', '.vscode', 'model_classes_3.ipynb', 'model_classes_full.ipynb', 'music_dataset_spectro_3_instrument', 'music_dataset_spectro_full', 'my_model_3.keras', 'my_model_full.keras', 'README.md', 'spectrogramMaker.py']
# ['Accordion', 'Acoustic_Guitar', 'Banjo', 'Bass_Guitar', 'Clarinet', 'cowbell', 'Dobro', 'Drum_set', 'Electric_Guitar', 'flute', 'Harmonium', 'Horn', 'Keyboard', 'Mandolin', 'Organ', 'Piano', 'Saxophone', 'Shakers', 'Tambourine', 'Trombone', 'Trumpet', 'Ukulele', 'vibraphone', 'Violin']

# %%
def get_dataset_array(data_dir):
    data = []
    for label in labels:
        print(label)
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
                gc.collect()
            except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
train = get_dataset_array("music_dataset_spectro_full/train/")
test = get_dataset_array("music_dataset_spectro_full/test/")
valid = get_dataset_array("music_dataset_spectro_full/valid/")
# Out:
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin

# %%
print(train.shape)
print(test.shape)
print(valid.shape)
# Out:
# (32888, 2)
# (4111, 2)
# (4123, 2)

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)

for feature, label in valid:
    x_val.append(feature)
    y_val.append(label)
     
del train
del test
del valid

# %%
gc.collect()
x_train = np.array(x_train)/255
gc.collect()
x_test = np.array(x_test)/255
gc.collect()
x_val = np.array(x_val)/255
gc.collect()
# Out:
# 0

# %%
x_train = x_train.reshape(-1, img_size, img_size, 3)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 3)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 3)
y_test = np.array(y_test)

# %%
# Model setup
model = Sequential()

model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = (img_size, img_size, 3)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())

model.add(Conv2D(64, (3,3), activation = 'relu', input_shape = (img_size, img_size, 3)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())

model.add(Conv2D(128, (3,3), activation = 'relu', input_shape = (img_size, img_size, 3)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 24, activation = 'sigmoid'))

model.compile(
              optimizer = 'adam', loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy']
              )

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 63, 63, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 30, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │         3,096 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,308,632 (12.62 MB)
#  Trainable params: 3,308,184 (12.62 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(

      featurewise_center=False,
      samplewise_center=False,
      featurewise_std_normalization=False,
      samplewise_std_normalization=False,
      zca_whitening=False,
      rotation_range = 30,
      zoom_range = 0.2,

      width_shift_range = 0.1,
      height_shift_range = 0.1,
      horizontal_flip = True,
      vertical_flip=False)


datagen.fit(x_train)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy', patience = 2, verbose = 1, factor = 0.3, min_lr = 0.000001)

# %%
batch_size = 32
n_epochs = 30
model.fit(datagen.flow(x_train, y_train, batch_size = batch_size),
                    epochs = n_epochs, validation_data = datagen.flow(x_val, y_val),
                    callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 186s 178ms/step - accuracy: 0.3256 - loss: 2.3297 - val_accuracy: 0.4232 - val_loss: 1.8937 - learning_rate: 0.0010
# Epoch 2/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 171s 166ms/step - accuracy: 0.3181 - loss: 1.9369 - val_accuracy: 0.3034 - val_loss: 1.9332 - learning_rate: 0.0010
# Epoch 3/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.2833 - loss: 1.8670
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 171s 167ms/step - accuracy: 0.2886 - loss: 1.8488 - val_accuracy: 0.4065 - val_loss: 1.8866 - learning_rate: 0.0010
# Epoch 4/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 170s 165ms/step - accuracy: 0.2833 - loss: 1.7086 - val_accuracy: 0.3437 - val_loss: 1.5510 - learning_rate: 3.0000e-04
# Epoch 5/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.2952 - loss: 1.6559
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 164ms/step - accuracy: 0.3022 - loss: 1.6310 - val_accuracy: 0.3796 - val_loss: 1.4799 - learning_rate: 3.0000e-04
# Epoch 6/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 169s 164ms/step - accuracy: 0.3187 - loss: 1.5272 - val_accuracy: 0.4383 - val_loss: 1.3323 - learning_rate: 9.0000e-05
# Epoch 7/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 171s 166ms/step - accuracy: 0.3432 - loss: 1.4709 - val_accuracy: 0.4599 - val_loss: 1.2282 - learning_rate: 9.0000e-05
# Epoch 8/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 163ms/step - accuracy: 0.3624 - loss: 1.4180 - val_accuracy: 0.4671 - val_loss: 1.1592 - learning_rate: 9.0000e-05
# Epoch 9/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 169s 164ms/step - accuracy: 0.3995 - loss: 1.3460 - val_accuracy: 0.5717 - val_loss: 0.9814 - learning_rate: 9.0000e-05
# Epoch 10/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 164ms/step - accuracy: 0.4404 - loss: 1.2585 - val_accuracy: 0.6454 - val_loss: 0.8326 - learning_rate: 9.0000e-05
# Epoch 11/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 167s 163ms/step - accuracy: 0.4793 - loss: 1.1782 - val_accuracy: 0.7148 - val_loss: 0.8022 - learning_rate: 9.0000e-05
# Epoch 12/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 167s 163ms/step - accuracy: 0.5134 - loss: 1.1101 - val_accuracy: 0.7237 - val_loss: 0.7102 - learning_rate: 9.0000e-05
# Epoch 13/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 167s 162ms/step - accuracy: 0.5436 - loss: 1.0468 - val_accuracy: 0.7582 - val_loss: 0.6677 - learning_rate: 9.0000e-05
# Epoch 14/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 163ms/step - accuracy: 0.5658 - loss: 1.0025 - val_accuracy: 0.7616 - val_loss: 0.6406 - learning_rate: 9.0000e-05
# Epoch 15/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 167s 162ms/step - accuracy: 0.5896 - loss: 0.9564 - val_accuracy: 0.7873 - val_loss: 0.6125 - learning_rate: 9.0000e-05
# Epoch 16/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 167s 163ms/step - accuracy: 0.5954 - loss: 0.9329 - val_accuracy: 0.8086 - val_loss: 0.5701 - learning_rate: 9.0000e-05
# Epoch 17/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 167s 162ms/step - accuracy: 0.6089 - loss: 0.9101 - val_accuracy: 0.8225 - val_loss: 0.5580 - learning_rate: 9.0000e-05
# Epoch 18/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 167s 162ms/step - accuracy: 0.6303 - loss: 0.8667 - val_accuracy: 0.8319 - val_loss: 0.5232 - learning_rate: 9.0000e-05
# Epoch 19/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 167s 162ms/step - accuracy: 0.6476 - loss: 0.8147 - val_accuracy: 0.8380 - val_loss: 0.5082 - learning_rate: 9.0000e-05
# Epoch 20/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 167s 163ms/step - accuracy: 0.6671 - loss: 0.7930 - val_accuracy: 0.8664 - val_loss: 0.4713 - learning_rate: 9.0000e-05
# Epoch 21/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 163ms/step - accuracy: 0.6844 - loss: 0.7560 - val_accuracy: 0.8627 - val_loss: 0.4554 - learning_rate: 9.0000e-05
# Epoch 22/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 167s 163ms/step - accuracy: 0.7089 - loss: 0.7027 - val_accuracy: 0.8693 - val_loss: 0.4328 - learning_rate: 9.0000e-05
# Epoch 23/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 163ms/step - accuracy: 0.7244 - loss: 0.6833 - val_accuracy: 0.8668 - val_loss: 0.4367 - learning_rate: 9.0000e-05
# Epoch 24/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7354 - loss: 0.6537
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 164ms/step - accuracy: 0.7350 - loss: 0.6501 - val_accuracy: 0.8634 - val_loss: 0.4570 - learning_rate: 9.0000e-05
# Epoch 25/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 163ms/step - accuracy: 0.7489 - loss: 0.6105 - val_accuracy: 0.8826 - val_loss: 0.3756 - learning_rate: 2.7000e-05
# Epoch 26/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 163ms/step - accuracy: 0.7530 - loss: 0.5993 - val_accuracy: 0.8846 - val_loss: 0.3766 - learning_rate: 2.7000e-05
# Epoch 27/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 163ms/step - accuracy: 0.7580 - loss: 0.5949 - val_accuracy: 0.8821 - val_loss: 0.3670 - learning_rate: 2.7000e-05
# Epoch 28/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 163ms/step - accuracy: 0.7640 - loss: 0.5729 - val_accuracy: 0.8909 - val_loss: 0.3574 - learning_rate: 2.7000e-05
# Epoch 29/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 168s 164ms/step - accuracy: 0.7702 - loss: 0.5651 - val_accuracy: 0.8884 - val_loss: 0.3593 - learning_rate: 2.7000e-05
# Epoch 30/30
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7683 - loss: 0.5526
# Epoch 30: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 169s 164ms/step - accuracy: 0.7694 - loss: 0.5503 - val_accuracy: 0.8872 - val_loss: 0.3424 - learning_rate: 2.7000e-05

# %%
gc.collect()
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
model.save('my_model_full.keras')
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.8545 - loss: 0.6097
# Accuracy of the model is -  85.45365929603577 %

# %%
img = cv2.imread("music_dataset_spectro_3_instrument/train/Drum_set/222_spect.png")
img=cv2.resize(img,(img_size,img_size))
img= np.reshape(img,(-1, img_size, img_size, 3))
img=img/255

print(labels)
labels=np.array(labels)
pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# ['Accordion' 'Acoustic_Guitar' 'Banjo' 'Bass_Guitar' 'Clarinet' 'cowbell'
#  'Dobro' 'Drum_set' 'Electric_Guitar' 'flute' 'Harmonium' 'Horn'
#  'Keyboard' 'Mandolin' 'Organ' 'Piano' 'Saxophone' 'Shakers' 'Tambourine'
#  'Trombone' 'Trumpet' 'Ukulele' 'vibraphone' 'Violin']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# ['Drum_set']
