# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.image import imread
from PIL import Image
import tensorflow as tf
np.random.seed(1337)
import gc

from tensorflow.keras import layers
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, AveragePooling2D,Flatten, Dense, Conv2D,MaxPool2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')


img_size = 128
print(os.listdir())
dataset = os.listdir("music_dataset_spectro_full/train")
labels = dataset
print(labels)
# Out:
# ['.git', '.vscode', 'model_classes_3.ipynb', 'model_classes_full.ipynb', 'music_dataset_spectro_3_instrument', 'music_dataset_spectro_full', 'my_model_3.keras', 'README.md', 'spectrogramMaker.py']
# ['Accordion', 'Acoustic_Guitar', 'Banjo', 'Bass_Guitar', 'Clarinet', 'cowbell', 'Cymbals', 'Dobro', 'Drum_set', 'Electric_Guitar', 'Floor_Tom', 'flute', 'Harmonica', 'Harmonium', 'Hi_Hats', 'Horn', 'Keyboard', 'Mandolin', 'Organ', 'Piano', 'Saxophone', 'Shakers', 'Tambourine', 'Trombone', 'Trumpet', 'Ukulele', 'vibraphone', 'Violin']

# %%
def get_dataset_array(data_dir):
    data = []
    for label in labels:
        print(label)
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
                gc.collect()
            except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
train = get_dataset_array("music_dataset_spectro_full/train/")
test = get_dataset_array("music_dataset_spectro_full/test/")
valid = get_dataset_array("music_dataset_spectro_full/valid/")
# Out:
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Cymbals
# Dobro
# Drum_set
# Electric_Guitar
# Floor_Tom
# flute
# Harmonica
# Harmonium
# Hi_Hats
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Cymbals
# Dobro
# Drum_set
# Electric_Guitar
# Floor_Tom
# flute
# Harmonica
# Harmonium
# Hi_Hats
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Cymbals
# Dobro
# Drum_set
# Electric_Guitar
# Floor_Tom
# flute
# Harmonica
# Harmonium
# Hi_Hats
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin

# %%
print(train.shape)
print(test.shape)
print(valid.shape)
# Out:
# (33837, 2)
# (4230, 2)
# (4244, 2)

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)

for feature, label in valid:
    x_val.append(feature)
    y_val.append(label)
     
del train
del test
del valid

# %%
gc.collect()
x_train = np.array(x_train)/255
gc.collect()
x_test = np.array(x_test)/255
gc.collect()
x_val = np.array(x_val)/255
gc.collect()
# Out:
# 0

# %%
x_train = x_train.reshape(-1, img_size, img_size, 3)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 3)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 3)
y_test = np.array(y_test)

# %%
# Model setup
model = Sequential()
model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = (img_size, img_size, 3)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), activation = 'relu', input_shape = (img_size, img_size, 3)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), activation = 'relu', input_shape = (img_size, img_size, 3)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 28, activation = 'softmax'))

model.compile(
              optimizer = 'adam', loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy']
              )

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 63, 63, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 30, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 22)             │         2,838 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,308,374 (12.62 MB)
#  Trainable params: 3,307,926 (12.62 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(

      featurewise_center=False,
      samplewise_center=False,
      featurewise_std_normalization=False,
      samplewise_std_normalization=False,
      zca_whitening=False,
      rotation_range = 30,
      zoom_range = 0.2,

      width_shift_range = 0.1,
      height_shift_range = 0.1,
      horizontal_flip = True,
      vertical_flip=False)


datagen.fit(x_train)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy', patience = 2, verbose = 1, factor = 0.3, min_lr = 0.000001)

# %%
batch_size = 32
n_epochs = 30
model.fit(datagen.flow(x_train, y_train, batch_size = batch_size),
                    epochs = n_epochs, validation_data = datagen.flow(x_val, y_val),
                    callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 193s 182ms/step - accuracy: 0.4601 - loss: 1.8169 - val_accuracy: 0.5547 - val_loss: 1.5593 - learning_rate: 0.0010
# Epoch 2/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 177s 167ms/step - accuracy: 0.4865 - loss: 1.7171 - val_accuracy: 0.5997 - val_loss: 1.3327 - learning_rate: 0.0010
# Epoch 3/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 175s 165ms/step - accuracy: 0.5137 - loss: 1.6079 - val_accuracy: 0.3459 - val_loss: 12.2459 - learning_rate: 0.0010
# Epoch 4/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 165ms/step - accuracy: 0.5388 - loss: 1.4904 - val_accuracy: 0.6374 - val_loss: 1.2084 - learning_rate: 0.0010
# Epoch 5/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.5743 - loss: 1.3805 - val_accuracy: 0.6185 - val_loss: 1.2546 - learning_rate: 0.0010
# Epoch 6/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 165ms/step - accuracy: 0.6069 - loss: 1.2714 - val_accuracy: 0.7267 - val_loss: 0.8798 - learning_rate: 0.0010
# Epoch 7/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.6324 - loss: 1.1937 - val_accuracy: 0.6934 - val_loss: 0.9497 - learning_rate: 0.0010
# Epoch 8/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6423 - loss: 1.1338
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.6436 - loss: 1.1318 - val_accuracy: 0.7026 - val_loss: 0.9374 - learning_rate: 0.0010
# Epoch 9/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.6672 - loss: 1.0420 - val_accuracy: 0.7491 - val_loss: 0.7862 - learning_rate: 3.0000e-04
# Epoch 10/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.6977 - loss: 0.9593 - val_accuracy: 0.7566 - val_loss: 0.7511 - learning_rate: 3.0000e-04
# Epoch 11/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 173s 164ms/step - accuracy: 0.7104 - loss: 0.9065 - val_accuracy: 0.8136 - val_loss: 0.6440 - learning_rate: 3.0000e-04
# Epoch 12/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.7237 - loss: 0.8652 - val_accuracy: 0.8174 - val_loss: 0.6349 - learning_rate: 3.0000e-04
# Epoch 13/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.7339 - loss: 0.8400 - val_accuracy: 0.8438 - val_loss: 0.5545 - learning_rate: 3.0000e-04
# Epoch 14/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.7466 - loss: 0.8006 - val_accuracy: 0.8450 - val_loss: 0.6311 - learning_rate: 3.0000e-04
# Epoch 15/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 175s 165ms/step - accuracy: 0.7594 - loss: 0.7569 - val_accuracy: 0.8617 - val_loss: 0.5441 - learning_rate: 3.0000e-04
# Epoch 16/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 176s 166ms/step - accuracy: 0.7679 - loss: 0.7244 - val_accuracy: 0.8292 - val_loss: 0.5738 - learning_rate: 3.0000e-04
# Epoch 17/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 173s 164ms/step - accuracy: 0.7796 - loss: 0.7049 - val_accuracy: 0.8657 - val_loss: 0.4696 - learning_rate: 3.0000e-04
# Epoch 18/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.7867 - loss: 0.6829 - val_accuracy: 0.8574 - val_loss: 0.5328 - learning_rate: 3.0000e-04
# Epoch 19/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 173s 164ms/step - accuracy: 0.7922 - loss: 0.6552 - val_accuracy: 0.8673 - val_loss: 0.4700 - learning_rate: 3.0000e-04
# Epoch 20/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.7955 - loss: 0.6447 - val_accuracy: 0.8770 - val_loss: 0.4294 - learning_rate: 3.0000e-04
# Epoch 21/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.8060 - loss: 0.6330 - val_accuracy: 0.8798 - val_loss: 0.4374 - learning_rate: 3.0000e-04
# Epoch 22/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 173s 163ms/step - accuracy: 0.8096 - loss: 0.6051 - val_accuracy: 0.8763 - val_loss: 0.4526 - learning_rate: 3.0000e-04
# Epoch 23/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.8178 - loss: 0.5863 - val_accuracy: 0.8893 - val_loss: 0.3593 - learning_rate: 3.0000e-04
# Epoch 24/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 173s 164ms/step - accuracy: 0.8212 - loss: 0.5702 - val_accuracy: 0.8867 - val_loss: 0.3909 - learning_rate: 3.0000e-04
# Epoch 25/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.8233 - loss: 0.5624 - val_accuracy: 0.8975 - val_loss: 0.3726 - learning_rate: 3.0000e-04
# Epoch 26/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.8369 - loss: 0.5345 - val_accuracy: 0.8926 - val_loss: 0.3848 - learning_rate: 3.0000e-04
# Epoch 27/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8360 - loss: 0.5360
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 175s 166ms/step - accuracy: 0.8377 - loss: 0.5310 - val_accuracy: 0.8935 - val_loss: 0.4036 - learning_rate: 3.0000e-04
# Epoch 28/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 175s 165ms/step - accuracy: 0.8448 - loss: 0.4925 - val_accuracy: 0.9062 - val_loss: 0.3405 - learning_rate: 9.0000e-05
# Epoch 29/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.8518 - loss: 0.4806 - val_accuracy: 0.9069 - val_loss: 0.3400 - learning_rate: 9.0000e-05
# Epoch 30/30
# 1058/1058 ━━━━━━━━━━━━━━━━━━━━ 174s 164ms/step - accuracy: 0.8538 - loss: 0.4728 - val_accuracy: 0.8935 - val_loss: 0.3627 - learning_rate: 9.0000e-05

# %%
gc.collect()
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
model.save('my_model_full.keras')
# Out:
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8246 - loss: 0.9357
# Accuracy of the model is -  82.4586272239685 %

# %%
img = cv2.imread("music_dataset_spectro_3_instrument/train/Acoustic_Guitar/222_spect.png")
img=cv2.resize(img,(img_size,img_size))
img= np.reshape(img,(-1, img_size, img_size, 3))
img=img/255

print(labels)
labels=np.array(labels)
pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# ['Accordion' 'Acoustic_Guitar' 'Banjo' 'Bass_Guitar' 'Clarinet' 'cowbell'
#  'Cymbals' 'Dobro' 'Drum_set' 'Electric_Guitar' 'Floor_Tom' 'flute'
#  'Harmonica' 'Harmonium' 'Hi_Hats' 'Horn' 'Keyboard' 'Mandolin' 'Organ'
#  'Piano' 'Saxophone' 'Shakers' 'Tambourine' 'Trombone' 'Trumpet' 'Ukulele'
#  'vibraphone' 'Violin']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# ['Acoustic_Guitar']
