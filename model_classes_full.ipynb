# %%
import os
import numpy as np
import cv2
np.random.seed(1337)
import gc

from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, Conv2D,MaxPool2D,BatchNormalization,GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MultiLabelBinarizer

img_size = 128 # set the image size to 128
print(os.listdir())
dataset = os.listdir("music_dataset_spectro_full_single/train") #use as labels
labels = dataset
print(labels)
# Out:
# ['.git', '.vscode', 'audio_separator_dataset', 'Checkpoint.keras', 'Checkpoint_tester.py', 'Classifiaction_model_full.keras', 'Classifiaction_model_full_multi.keras', 'Classifiaction_model_single.keras', 'large separation dataset output', 'longSongSplitter.py', 'Mix_maker.py', 'model saves', 'model_classes_full.ipynb', 'model_classes_full_multi.ipynb', 'model_classes_single.ipynb', 'model_separation(large dataset).ipynb', 'model_separation(small dataset).ipynb', 'music_dataset', 'music_dataset_spectro_full_single', 'Music_mixes_dataset_classification', 'Music_separation_dataset_large', 'music_separation_dataset_small', 'my_separator_model_prototype.keras', 'prediction images', 'README.md', 'separator_model_small.keras', 'small separation dataset output', 'spectrogramMaker.py', 'spectrogramMakerMix.py', 'spectrogramMakerStem.py', 'testing_classification_model_single.ipynb', 'Testing_sepration_model(small_dataset).ipynb', 'wavs from spectrograms']
# ['Accordion', 'Acoustic_Guitar', 'Banjo', 'Bass_Guitar', 'Clarinet', 'cowbell', 'Dobro', 'Drum_set', 'Electric_Guitar', 'flute', 'Harmonium', 'Horn', 'Keyboard', 'Mandolin', 'Organ', 'Piano', 'Saxophone', 'Shakers', 'Tambourine', 'Trombone', 'Trumpet', 'Ukulele', 'vibraphone', 'Violin']

# %%
def get_dataset_array_train(data_dir):
    data = []
    for label in labels: # loop through the labels
        print(label)
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path): # loop through images 
            try:
                img_arr = cv2.imread(os.path.join(path, img),0)
                resized_arr = img_arr[:img_size,:img_size] # slice the image to be 128 128
                data.append([resized_arr, [class_num]]) # append label number and instrument spectrogram
                gc.collect() 
            except Exception as e:
                print(e)

    path = os.path.join("Music_mixes_dataset_classification/train/"+"mix")
    for img in os.listdir("Music_mixes_dataset_classification/train/"+"mix"): #loop through mixes
        class_num = []
        for stem in os.listdir("Music_mixes_dataset_classification/train/"+"stems"):
            if img.split("_")[0] == stem.split("_")[0]:
                temp=stem.split("_",1)
                label = temp[1].split(".")[0] #split names so the instruments are used as labels
                class_num.append(labels.index(label))

        try:
            img_arr = cv2.imread(os.path.join(path,img),0)
            resized_arr =img_arr[:img_size,:img_size]
            data.append([resized_arr,class_num])
            gc.collect()
        except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
def get_dataset_array_test(data_dir):
    data = []
    for label in labels: # loop through the labels
        print(label)
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path): # loop through images 
            try:
                img_arr = cv2.imread(os.path.join(path, img),0)
                resized_arr = img_arr[:img_size,:img_size] # slice the image to be 128 128
                data.append([resized_arr, [class_num]]) # append label number and instrument spectrogram
                gc.collect()
            except Exception as e:
                print(e)

    path = os.path.join("Music_mixes_dataset_classification/test/"+"mix")
    for img in os.listdir("Music_mixes_dataset_classification/test/"+"mix"):#loop through mixes
        class_num = []
        for stem in os.listdir("Music_mixes_dataset_classification/test/"+"stems"):
            if img.split("_")[0] == stem.split("_")[0]:
                temp=stem.split("_",1)
                label = temp[1].split(".")[0]  #split names so the instruments are used as labels
                class_num.append(labels.index(label))

        try:
            img_arr = cv2.imread(os.path.join(path,img),0)
            resized_arr = img_arr[:img_size,:img_size]
            data.append([resized_arr,class_num])
            gc.collect()
        except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
def get_dataset_array_valid(data_dir):
    data = []
    for label in labels: # loop through the labels
        print(label)
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img),0)
                resized_arr = img_arr[:img_size,:img_size] # slice the image to be 128 128
                data.append([resized_arr, [class_num]])# append label number and instrument spectrogram
                gc.collect()
            except Exception as e:
                print(e)

    path = os.path.join("Music_mixes_dataset_classification/valid/"+"mix")
    for img in os.listdir("Music_mixes_dataset_classification/valid/"+"mix"):#loop through mixes
        class_num = []
        for stem in os.listdir("Music_mixes_dataset_classification/valid/"+"stems"):
            if img.split("_")[0] == stem.split("_")[0]:
                temp=stem.split("_",1)
                label = temp[1].split(".")[0] #split names so the instruments are used as labels
                class_num.append(labels.index(label))

        try:
            img_arr = cv2.imread(os.path.join(path,img),0)
            resized_arr = img_arr[:img_size,:img_size]
            data.append([resized_arr,class_num])
            gc.collect()
        except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
train = get_dataset_array_train("music_dataset_spectro_full_single/train/")
test = get_dataset_array_test("music_dataset_spectro_full_single/test/")
valid = get_dataset_array_valid("music_dataset_spectro_full_single/valid/")
# Out:
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin

# %%
print(train.shape) # see the shapes
print(test.shape) # see the shapes
print(valid.shape) # see the shapes
# Out:
# (65721, 2)
# (8216, 2)
# (8232, 2)

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train: #loop through the train array and split into x image and y labels
    x_train.append(feature)
    y_train.append(label)

del train

for feature, label in test:#loop through the test array and split into x image and y labels
    x_test.append(feature)
    y_test.append(label)
del test

for feature, label in valid:#loop through the valid array and split into x image and y labels
    x_val.append(feature)
    y_val.append(label)
     
del valid

# %%
gc.collect()
x_train = np.array(x_train)/255 #normalize the images
gc.collect()
x_test = np.array(x_test)/255 #normalize the images
gc.collect()
x_val = np.array(x_val)/255 #normalize the images
gc.collect()
# Out:
# 0

# %%
x_train = x_train.reshape(-1, img_size, img_size, 1) # reshape images

mlb = MultiLabelBinarizer() # to make the labels multi hot

y_train = mlb.fit_transform(y_train) # make the labels multi hot

x_val = x_val.reshape(-1, img_size, img_size, 1) # reshape images

y_val = mlb.fit_transform(y_val) # make the labels multi hot


x_test = x_test.reshape(-1, img_size, img_size, 1) # reshape images

y_test = mlb.fit_transform(y_test)  # make the labels multi hot

# %%
# Model setup
model = Sequential()

#first block
model.add(Conv2D(32, (3,3), activation = 'relu', padding="same", input_shape = (img_size, img_size, 1))) # input the image shape
model.add(BatchNormalization())  # normalize image
model.add(Conv2D(32, (3,3), activation = 'relu', padding="same")) 
model.add(MaxPool2D((2,2))) # downsample image

#second block
model.add(Conv2D(64, (3,3), activation = 'relu', padding="same"))
model.add(BatchNormalization()) # normalize image
model.add(Conv2D(64, (3,3), activation = 'relu', padding="same"))
model.add(MaxPool2D((2,2))) # downsample image

#third block
model.add(Conv2D(128, (3,3), activation = 'relu', padding="same"))
model.add(BatchNormalization()) # normalize image
model.add(Conv2D(128, (3,3), activation = 'relu', padding="same"))
model.add(GlobalAveragePooling2D())

#last block
model.add(Dense(units = 512, activation = 'relu')) #dense layer
model.add(Dropout(0.4))
model.add(Dense(units = 24, activation = 'sigmoid'))

model.compile(
              optimizer = 'adam', loss = 'binary_crossentropy',
              metrics = ['binary_accuracy',]
              )

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │        12,312 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 365,688 (1.39 MB)
#  Trainable params: 365,240 (1.39 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
print(x_train.shape) 
print(y_train.shape)
# Out:
# (65721, 128, 128, 1)
# (65721, 24)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_binary_accuracy', patience = 2, verbose = 1, factor = 0.3, min_lr = 0.000001)
stop_early = EarlyStopping("val_binary_accuracy",patience = 3, verbose = 1)

# %%
batch_size = 32
n_epochs = 50
model.fit(x_train, y_train, batch_size = batch_size,
                    epochs = n_epochs, validation_data = (x_val, y_val),
                    callbacks = [learning_rate_reduction,stop_early], shuffle = True)
# Out:
# Epoch 1/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 921s 446ms/step - accuracy: 0.3774 - binary_accuracy: 0.9350 - loss: 0.2239 - val_accuracy: 0.3551 - val_binary_accuracy: 0.9364 - val_loss: 0.2301 - learning_rate: 0.0010
# Epoch 2/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 892s 434ms/step - accuracy: 0.4597 - binary_accuracy: 0.9399 - loss: 0.2042 - val_accuracy: 0.4280 - val_binary_accuracy: 0.9371 - val_loss: 0.2198 - learning_rate: 0.0010
# Epoch 3/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 899s 437ms/step - accuracy: 0.4787 - binary_accuracy: 0.9417 - loss: 0.1975 - val_accuracy: 0.4261 - val_binary_accuracy: 0.9386 - val_loss: 0.2065 - learning_rate: 0.0010
# Epoch 4/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 892s 434ms/step - accuracy: 0.4892 - binary_accuracy: 0.9427 - loss: 0.1934 - val_accuracy: 0.4715 - val_binary_accuracy: 0.9410 - val_loss: 0.2026 - learning_rate: 0.0010
# Epoch 5/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 892s 434ms/step - accuracy: 0.4960 - binary_accuracy: 0.9434 - loss: 0.1904 - val_accuracy: 0.4749 - val_binary_accuracy: 0.9419 - val_loss: 0.1942 - learning_rate: 0.0010
# Epoch 6/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 892s 434ms/step - accuracy: 0.5014 - binary_accuracy: 0.9439 - loss: 0.1885 - val_accuracy: 0.4940 - val_binary_accuracy: 0.9428 - val_loss: 0.1926 - learning_rate: 0.0010
# Epoch 7/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 892s 434ms/step - accuracy: 0.5051 - binary_accuracy: 0.9441 - loss: 0.1868 - val_accuracy: 0.4840 - val_binary_accuracy: 0.9435 - val_loss: 0.1899 - learning_rate: 0.0010
# Epoch 8/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 892s 434ms/step - accuracy: 0.5081 - binary_accuracy: 0.9445 - loss: 0.1853 - val_accuracy: 0.4951 - val_binary_accuracy: 0.9440 - val_loss: 0.1873 - learning_rate: 0.0010
# Epoch 9/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 892s 434ms/step - accuracy: 0.5083 - binary_accuracy: 0.9448 - loss: 0.1841 - val_accuracy: 0.4009 - val_binary_accuracy: 0.9387 - val_loss: 0.2068 - learning_rate: 0.0010
# Epoch 10/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.5111 - binary_accuracy: 0.9453 - loss: 0.1819
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 893s 435ms/step - accuracy: 0.5095 - binary_accuracy: 0.9450 - loss: 0.1828 - val_accuracy: 0.4662 - val_binary_accuracy: 0.9387 - val_loss: 0.2154 - learning_rate: 0.0010
# Epoch 11/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 891s 434ms/step - accuracy: 0.5140 - binary_accuracy: 0.9459 - loss: 0.1784 - val_accuracy: 0.4990 - val_binary_accuracy: 0.9441 - val_loss: 0.1875 - learning_rate: 3.0000e-04
# Epoch 12/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 892s 434ms/step - accuracy: 0.5164 - binary_accuracy: 0.9461 - loss: 0.1770 - val_accuracy: 0.5075 - val_binary_accuracy: 0.9447 - val_loss: 0.1853 - learning_rate: 3.0000e-04
# Epoch 13/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 892s 434ms/step - accuracy: 0.5166 - binary_accuracy: 0.9462 - loss: 0.1763 - val_accuracy: 0.4987 - val_binary_accuracy: 0.9442 - val_loss: 0.1866 - learning_rate: 3.0000e-04
# Epoch 14/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.5194 - binary_accuracy: 0.9464 - loss: 0.1757
# Epoch 14: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 893s 435ms/step - accuracy: 0.5174 - binary_accuracy: 0.9463 - loss: 0.1760 - val_accuracy: 0.4973 - val_binary_accuracy: 0.9447 - val_loss: 0.1857 - learning_rate: 3.0000e-04
# Epoch 15/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 912s 444ms/step - accuracy: 0.5167 - binary_accuracy: 0.9466 - loss: 0.1742 - val_accuracy: 0.5086 - val_binary_accuracy: 0.9452 - val_loss: 0.1843 - learning_rate: 9.0000e-05
# Epoch 16/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 891s 434ms/step - accuracy: 0.5183 - binary_accuracy: 0.9466 - loss: 0.1737 - val_accuracy: 0.5079 - val_binary_accuracy: 0.9451 - val_loss: 0.1863 - learning_rate: 9.0000e-05
# Epoch 17/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.5199 - binary_accuracy: 0.9467 - loss: 0.1733
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 891s 434ms/step - accuracy: 0.5190 - binary_accuracy: 0.9467 - loss: 0.1735 - val_accuracy: 0.5045 - val_binary_accuracy: 0.9451 - val_loss: 0.1852 - learning_rate: 9.0000e-05
# Epoch 18/50
# 2054/2054 ━━━━━━━━━━━━━━━━━━━━ 892s 434ms/step - accuracy: 0.5192 - binary_accuracy: 0.9468 - loss: 0.1729 - val_accuracy: 0.5041 - val_binary_accuracy: 0.9451 - val_loss: 0.1851 - learning_rate: 2.7000e-05
# Epoch 18: early stopping

# %%
gc.collect()
print("loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
model.save('Classifiaction_model_full.keras')
# Out:
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 25s 97ms/step - accuracy: 0.5002 - binary_accuracy: 0.9445 - loss: 0.1878
# loss of the model is -  0.18778569996356964
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 25s 96ms/step - accuracy: 0.5002 - binary_accuracy: 0.9445 - loss: 0.1878
# Accuracy of the model is -  94.44833397865295 %

# %%
predictions=model.predict(x_test)
pred_labels= np.where(predictions>0.5)
# Out:
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 25s 96ms/step

# %%
img = cv2.imread("music_dataset_spectro_full_single/test/Accordion/2864_Accordion.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

print(labels)
labels=np.array(labels)
pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# ['Accordion', 'Acoustic_Guitar', 'Banjo', 'Bass_Guitar', 'Clarinet', 'cowbell', 'Dobro', 'Drum_set', 'Electric_Guitar', 'flute', 'Harmonium', 'Horn', 'Keyboard', 'Mandolin', 'Organ', 'Piano', 'Saxophone', 'Shakers', 'Tambourine', 'Trombone', 'Trumpet', 'Ukulele', 'vibraphone', 'Violin']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ['Accordion']

# %%
img = cv2.imread("Music_mixes_dataset_classification/test/mix/32836_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

print(labels)
labels=np.array(labels)
pred=model.predict(img)
print(pred)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# ['Accordion' 'Acoustic_Guitar' 'Banjo' 'Bass_Guitar' 'Clarinet' 'cowbell'
#  'Dobro' 'Drum_set' 'Electric_Guitar' 'flute' 'Harmonium' 'Horn'
#  'Keyboard' 'Mandolin' 'Organ' 'Piano' 'Saxophone' 'Shakers' 'Tambourine'
#  'Trombone' 'Trumpet' 'Ukulele' 'vibraphone' 'Violin']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[0.10788307 0.10451518 0.11009921 0.11871445 0.11535736 0.10704157
#   0.11414631 0.11222664 0.10938971 0.0998868  0.11971595 0.11380181
#   0.10690745 0.11081319 0.11617751 0.11518886 0.10616703 0.11323859
#   0.10798607 0.10394621 0.10581025 0.11693541 0.10379705 0.11782876]]
# ['Harmonium']

# %%
img = cv2.imread("Music_mixes_dataset_classification/test/mix/32844_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

print(labels)
labels=np.array(labels)
pred=model.predict(img)
print(pred)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# ['Accordion' 'Acoustic_Guitar' 'Banjo' 'Bass_Guitar' 'Clarinet' 'cowbell'
#  'Dobro' 'Drum_set' 'Electric_Guitar' 'flute' 'Harmonium' 'Horn'
#  'Keyboard' 'Mandolin' 'Organ' 'Piano' 'Saxophone' 'Shakers' 'Tambourine'
#  'Trombone' 'Trumpet' 'Ukulele' 'vibraphone' 'Violin']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# [[0.09342603 0.09740506 0.08928633 0.09374812 0.09686755 0.09915767
#   0.09450397 0.09804794 0.09324158 0.10538106 0.08334931 0.10615671
#   0.10118494 0.10843963 0.10507583 0.09634153 0.09045126 0.09442893
#   0.09720422 0.10970211 0.09607217 0.08479447 0.10471403 0.10100286]]
# ['Trombone']
