# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.image import imread
from PIL import Image
import tensorflow as tf
np.random.seed(1337)
import gc

from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, AveragePooling2D,Flatten, Dense, Conv2D,MaxPool2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')


img_size = 128
print(os.listdir())
dataset = os.listdir("music_dataset_spectro_full/train")
labels = dataset
print(labels)
# Out:
# ['.git', '.vscode', 'drum_part.wav', 'drum_prediction.wav', 'full.wav', 'model_classes_3.ipynb', 'model_classes_full.ipynb', 'model_separation.ipynb', 'music_dataset_spectro_3_instrument', 'music_dataset_spectro_full', 'music_seperation_dataset', 'my_model_3.keras', 'my_model_full.keras', 'my_separator_model_prototype.keras', 'README.md', 'separated_part.png', 'separated_part_1_batch.png', 'spectrogramMaker.py']
# ['Accordion', 'Acoustic_Guitar', 'Banjo', 'Bass_Guitar', 'Clarinet', 'cowbell', 'Dobro', 'Drum_set', 'Electric_Guitar', 'flute', 'Harmonium', 'Horn', 'Keyboard', 'Mandolin', 'Organ', 'Piano', 'Saxophone', 'Shakers', 'Tambourine', 'Trombone', 'Trumpet', 'Ukulele', 'vibraphone', 'Violin']

# %%
def get_dataset_array(data_dir):
    data = []
    for label in labels:
        print(label)
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img),0)
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
                gc.collect()
            except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
train = get_dataset_array("music_dataset_spectro_full/train/")
test = get_dataset_array("music_dataset_spectro_full/test/")
valid = get_dataset_array("music_dataset_spectro_full/valid/")
# Out:
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin

# %%
print(train.shape)
print(test.shape)
print(valid.shape)
# Out:
# (32888, 2)
# (4117, 2)
# (4129, 2)

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)

for feature, label in valid:
    x_val.append(feature)
    y_val.append(label)
     
del train
del test
del valid

# %%
gc.collect()
x_train = np.array(x_train)/255
gc.collect()
x_test = np.array(x_test)/255
gc.collect()
x_val = np.array(x_val)/255
gc.collect()
# Out:
# 0

# %%
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)
y_train = to_categorical(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)
y_val = to_categorical(y_val)


x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)
y_test = to_categorical(y_test)

# %%
# Model setup
model = Sequential()

model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = (img_size, img_size, 1)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())

model.add(Conv2D(64, (3,3), activation = 'relu', input_shape = (img_size, img_size, 1)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())

model.add(Conv2D(128, (3,3), activation = 'relu', input_shape = (img_size, img_size, 1)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 24, activation = 'sigmoid'))

model.compile(
              optimizer = 'adam', loss = 'binary_crossentropy',
              metrics = ['accuracy']
              )

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 63, 63, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 30, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │         3,096 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,308,056 (12.62 MB)
#  Trainable params: 3,307,608 (12.62 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (32888, 128, 128, 1)
# (32888, 24)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy', patience = 2, verbose = 1, factor = 0.3, min_lr = 0.000001)

# %%
batch_size = 32
n_epochs = 50
model.fit(x_train, y_train, batch_size = batch_size,
                    epochs = n_epochs, validation_data = (x_val, y_val),
                    callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 137ms/step - accuracy: 0.6700 - loss: 0.1153 - val_accuracy: 0.8581 - val_loss: 0.0398 - learning_rate: 0.0010
# Epoch 2/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.8589 - loss: 0.0393 - val_accuracy: 0.9283 - val_loss: 0.0271 - learning_rate: 0.0010
# Epoch 3/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9112 - loss: 0.0262 - val_accuracy: 0.9017 - val_loss: 0.0444 - learning_rate: 0.0010
# Epoch 4/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9338 - loss: 0.0201
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9382 - loss: 0.0187 - val_accuracy: 0.8934 - val_loss: 0.0312 - learning_rate: 0.0010
# Epoch 5/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9655 - loss: 0.0115 - val_accuracy: 0.9646 - val_loss: 0.0124 - learning_rate: 3.0000e-04
# Epoch 6/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9728 - loss: 0.0090 - val_accuracy: 0.9598 - val_loss: 0.0135 - learning_rate: 3.0000e-04
# Epoch 7/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.9793 - loss: 0.0072 - val_accuracy: 0.9690 - val_loss: 0.0128 - learning_rate: 3.0000e-04
# Epoch 8/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9829 - loss: 0.0064 - val_accuracy: 0.9644 - val_loss: 0.0134 - learning_rate: 3.0000e-04
# Epoch 9/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9868 - loss: 0.0054
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9875 - loss: 0.0052 - val_accuracy: 0.9685 - val_loss: 0.0122 - learning_rate: 3.0000e-04
# Epoch 10/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9901 - loss: 0.0039 - val_accuracy: 0.9746 - val_loss: 0.0098 - learning_rate: 9.0000e-05
# Epoch 11/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9924 - loss: 0.0032 - val_accuracy: 0.9721 - val_loss: 0.0099 - learning_rate: 9.0000e-05
# Epoch 12/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9930 - loss: 0.0031
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9931 - loss: 0.0031 - val_accuracy: 0.9736 - val_loss: 0.0110 - learning_rate: 9.0000e-05
# Epoch 13/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9943 - loss: 0.0027 - val_accuracy: 0.9738 - val_loss: 0.0106 - learning_rate: 2.7000e-05
# Epoch 14/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9941 - loss: 0.0026 - val_accuracy: 0.9770 - val_loss: 0.0105 - learning_rate: 2.7000e-05
# Epoch 15/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9949 - loss: 0.0024 - val_accuracy: 0.9758 - val_loss: 0.0109 - learning_rate: 2.7000e-05
# Epoch 16/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9940 - loss: 0.0027
# Epoch 16: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9943 - loss: 0.0025 - val_accuracy: 0.9755 - val_loss: 0.0112 - learning_rate: 2.7000e-05
# Epoch 17/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9941 - loss: 0.0025 - val_accuracy: 0.9780 - val_loss: 0.0106 - learning_rate: 8.1000e-06
# Epoch 18/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9950 - loss: 0.0022 - val_accuracy: 0.9760 - val_loss: 0.0110 - learning_rate: 8.1000e-06
# Epoch 19/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9943 - loss: 0.0025 - val_accuracy: 0.9784 - val_loss: 0.0104 - learning_rate: 8.1000e-06
# Epoch 20/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9946 - loss: 0.0024 - val_accuracy: 0.9777 - val_loss: 0.0107 - learning_rate: 8.1000e-06
# Epoch 21/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9946 - loss: 0.0022
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9948 - loss: 0.0023 - val_accuracy: 0.9772 - val_loss: 0.0108 - learning_rate: 8.1000e-06
# Epoch 22/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9954 - loss: 0.0023 - val_accuracy: 0.9765 - val_loss: 0.0109 - learning_rate: 2.4300e-06
# Epoch 23/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9956 - loss: 0.0023
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 142s 138ms/step - accuracy: 0.9957 - loss: 0.0022 - val_accuracy: 0.9772 - val_loss: 0.0107 - learning_rate: 2.4300e-06
# Epoch 24/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9951 - loss: 0.0022 - val_accuracy: 0.9770 - val_loss: 0.0108 - learning_rate: 1.0000e-06
# Epoch 25/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9953 - loss: 0.0021 - val_accuracy: 0.9767 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 26/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9950 - loss: 0.0022 - val_accuracy: 0.9770 - val_loss: 0.0108 - learning_rate: 1.0000e-06
# Epoch 27/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9954 - loss: 0.0022 - val_accuracy: 0.9765 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 28/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 138ms/step - accuracy: 0.9961 - loss: 0.0020 - val_accuracy: 0.9767 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 29/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 142s 138ms/step - accuracy: 0.9955 - loss: 0.0021 - val_accuracy: 0.9770 - val_loss: 0.0108 - learning_rate: 1.0000e-06
# Epoch 30/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9957 - loss: 0.0021 - val_accuracy: 0.9772 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 31/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9951 - loss: 0.0021 - val_accuracy: 0.9767 - val_loss: 0.0108 - learning_rate: 1.0000e-06
# Epoch 32/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9956 - loss: 0.0021 - val_accuracy: 0.9767 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 33/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9957 - loss: 0.0020 - val_accuracy: 0.9772 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 34/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9954 - loss: 0.0021 - val_accuracy: 0.9772 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 35/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9957 - loss: 0.0021 - val_accuracy: 0.9765 - val_loss: 0.0110 - learning_rate: 1.0000e-06
# Epoch 36/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9953 - loss: 0.0022 - val_accuracy: 0.9770 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 37/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 142s 138ms/step - accuracy: 0.9952 - loss: 0.0022 - val_accuracy: 0.9767 - val_loss: 0.0110 - learning_rate: 1.0000e-06
# Epoch 38/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 138ms/step - accuracy: 0.9957 - loss: 0.0021 - val_accuracy: 0.9765 - val_loss: 0.0110 - learning_rate: 1.0000e-06
# Epoch 39/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9954 - loss: 0.0021 - val_accuracy: 0.9770 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 40/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 142s 138ms/step - accuracy: 0.9956 - loss: 0.0021 - val_accuracy: 0.9770 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 41/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9956 - loss: 0.0020 - val_accuracy: 0.9765 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 42/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9956 - loss: 0.0021 - val_accuracy: 0.9770 - val_loss: 0.0110 - learning_rate: 1.0000e-06
# Epoch 43/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9956 - loss: 0.0021 - val_accuracy: 0.9775 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 44/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9956 - loss: 0.0021 - val_accuracy: 0.9772 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 45/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 138ms/step - accuracy: 0.9952 - loss: 0.0022 - val_accuracy: 0.9765 - val_loss: 0.0110 - learning_rate: 1.0000e-06
# Epoch 46/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9951 - loss: 0.0022 - val_accuracy: 0.9777 - val_loss: 0.0108 - learning_rate: 1.0000e-06
# Epoch 47/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9953 - loss: 0.0021 - val_accuracy: 0.9770 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 48/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9955 - loss: 0.0021 - val_accuracy: 0.9772 - val_loss: 0.0109 - learning_rate: 1.0000e-06
# Epoch 49/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 138ms/step - accuracy: 0.9957 - loss: 0.0020 - val_accuracy: 0.9767 - val_loss: 0.0110 - learning_rate: 1.0000e-06
# Epoch 50/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 141s 137ms/step - accuracy: 0.9960 - loss: 0.0021 - val_accuracy: 0.9775 - val_loss: 0.0110 - learning_rate: 1.0000e-06

# %%
gc.collect()
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
model.save('my_model_full.keras')
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9777 - loss: 0.0128
# Accuracy of the model is -  97.76536226272583 %

# %%
img = cv2.imread("music_dataset_spectro_full/test/dobro/389_dobro.png",0)
img=cv2.resize(img,(img_size,img_size))
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

print(labels)
labels=np.array(labels)
pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# ['Accordion', 'Acoustic_Guitar', 'Banjo', 'Bass_Guitar', 'Clarinet', 'cowbell', 'Dobro', 'Drum_set', 'Electric_Guitar', 'flute', 'Harmonium', 'Horn', 'Keyboard', 'Mandolin', 'Organ', 'Piano', 'Saxophone', 'Shakers', 'Tambourine', 'Trombone', 'Trumpet', 'Ukulele', 'vibraphone', 'Violin']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# ['Dobro']
