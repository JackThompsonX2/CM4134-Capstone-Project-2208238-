# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.image import imread
from PIL import Image
import tensorflow as tf
np.random.seed(1337)
import gc

from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, AveragePooling2D,Flatten, Dense, Conv2D,MaxPool2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')


img_size = 128
print(os.listdir())
dataset = os.listdir("music_dataset_spectro_full/train")
labels = dataset
print(labels)
# Out:
# ['.git', '.vscode', 'mask.png', 'model_classes_3.ipynb', 'model_classes_full.ipynb', 'model_separation.ipynb', 'music_dataset_spectro_3_instrument', 'music_dataset_spectro_full', 'music_seperation_dataset', 'my_model_3.keras', 'my_model_full.keras', 'my_separator_model_full.keras', 'README.md', 'spectrogramMaker.py']
# ['Accordion', 'Acoustic_Guitar', 'Banjo', 'Bass_Guitar', 'Clarinet', 'cowbell', 'Dobro', 'Drum_set', 'Electric_Guitar', 'flute', 'Harmonium', 'Horn', 'Keyboard', 'Mandolin', 'Organ', 'Piano', 'Saxophone', 'Shakers', 'Tambourine', 'Trombone', 'Trumpet', 'Ukulele', 'vibraphone', 'Violin']

# %%
def get_dataset_array(data_dir):
    data = []
    for label in labels:
        print(label)
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
                gc.collect()
            except Exception as e:
                print(e)
    return np.array(data,dtype="object")

# %%
train = get_dataset_array("music_dataset_spectro_full/train/")
test = get_dataset_array("music_dataset_spectro_full/test/")
valid = get_dataset_array("music_dataset_spectro_full/valid/")
# Out:
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin
# Accordion
# Acoustic_Guitar
# Banjo
# Bass_Guitar
# Clarinet
# cowbell
# Dobro
# Drum_set
# Electric_Guitar
# flute
# Harmonium
# Horn
# Keyboard
# Mandolin
# Organ
# Piano
# Saxophone
# Shakers
# Tambourine
# Trombone
# Trumpet
# Ukulele
# vibraphone
# Violin

# %%
print(train.shape)
print(test.shape)
print(valid.shape)
# Out:
# (32888, 2)
# (4111, 2)
# (4123, 2)

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)

for feature, label in valid:
    x_val.append(feature)
    y_val.append(label)
     
del train
del test
del valid

# %%
gc.collect()
x_train = np.array(x_train)/255
gc.collect()
x_test = np.array(x_test)/255
gc.collect()
x_val = np.array(x_val)/255
gc.collect()
# Out:
# 0

# %%
x_train = x_train.reshape(-1, img_size, img_size, 3)
y_train = np.array(y_train)
y_train = to_categorical(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 3)
y_val = np.array(y_val)
y_val = to_categorical(y_val)


x_test = x_test.reshape(-1, img_size, img_size, 3)
y_test = np.array(y_test)
y_test = to_categorical(y_test)

# %%
# Model setup
model = Sequential()

model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = (img_size, img_size, 3)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())

model.add(Conv2D(64, (3,3), activation = 'relu', input_shape = (img_size, img_size, 3)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())

model.add(Conv2D(128, (3,3), activation = 'relu', input_shape = (img_size, img_size, 3)))
model.add(MaxPool2D((2,2)))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 24, activation = 'sigmoid'))

model.compile(
              optimizer = 'adam', loss = 'binary_crossentropy',
              metrics = ['accuracy']
              )

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 63, 63, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 30, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │         3,096 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,308,632 (12.62 MB)
#  Trainable params: 3,308,184 (12.62 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy', patience = 2, verbose = 1, factor = 0.3, min_lr = 0.000001)

# %%
batch_size = 32
n_epochs = 50
model.fit(x_train, y_train, batch_size = batch_size,
                    epochs = n_epochs, validation_data = (x_val, y_val),
                    callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.3891 - loss: 0.1681 - val_accuracy: 0.7478 - val_loss: 0.0686 - learning_rate: 0.0010
# Epoch 2/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.5426 - loss: 0.1031 - val_accuracy: 0.8011 - val_loss: 0.0521 - learning_rate: 0.0010
# Epoch 3/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 140ms/step - accuracy: 0.5873 - loss: 0.0886 - val_accuracy: 0.8169 - val_loss: 0.0532 - learning_rate: 0.0010
# Epoch 4/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.6217 - loss: 0.0793 - val_accuracy: 0.8520 - val_loss: 0.0465 - learning_rate: 0.0010
# Epoch 5/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.6529 - loss: 0.0710 - val_accuracy: 0.8814 - val_loss: 0.0432 - learning_rate: 0.0010
# Epoch 6/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.6842 - loss: 0.0649 - val_accuracy: 0.8610 - val_loss: 0.0398 - learning_rate: 0.0010
# Epoch 7/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.6983 - loss: 0.0620 - val_accuracy: 0.8938 - val_loss: 0.0335 - learning_rate: 0.0010
# Epoch 8/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.7128 - loss: 0.0588 - val_accuracy: 0.9032 - val_loss: 0.0371 - learning_rate: 0.0010
# Epoch 9/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.7449 - loss: 0.0536 - val_accuracy: 0.9154 - val_loss: 0.0313 - learning_rate: 0.0010
# Epoch 10/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.7671 - loss: 0.0486 - val_accuracy: 0.9178 - val_loss: 0.0284 - learning_rate: 0.0010
# Epoch 11/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.7880 - loss: 0.0454 - val_accuracy: 0.9406 - val_loss: 0.0253 - learning_rate: 0.0010
# Epoch 12/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.8081 - loss: 0.0414 - val_accuracy: 0.9171 - val_loss: 0.0312 - learning_rate: 0.0010
# Epoch 13/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8275 - loss: 0.0380
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.8323 - loss: 0.0375 - val_accuracy: 0.9272 - val_loss: 0.0273 - learning_rate: 0.0010
# Epoch 14/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.8633 - loss: 0.0309 - val_accuracy: 0.9529 - val_loss: 0.0195 - learning_rate: 3.0000e-04
# Epoch 15/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.8845 - loss: 0.0268 - val_accuracy: 0.9576 - val_loss: 0.0177 - learning_rate: 3.0000e-04
# Epoch 16/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9035 - loss: 0.0229 - val_accuracy: 0.9639 - val_loss: 0.0165 - learning_rate: 3.0000e-04
# Epoch 17/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9262 - loss: 0.0187 - val_accuracy: 0.9658 - val_loss: 0.0159 - learning_rate: 3.0000e-04
# Epoch 18/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 140ms/step - accuracy: 0.9487 - loss: 0.0142 - val_accuracy: 0.9687 - val_loss: 0.0129 - learning_rate: 3.0000e-04
# Epoch 19/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 140ms/step - accuracy: 0.9614 - loss: 0.0114 - val_accuracy: 0.9677 - val_loss: 0.0136 - learning_rate: 3.0000e-04
# Epoch 20/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9700 - loss: 0.0092 - val_accuracy: 0.9707 - val_loss: 0.0131 - learning_rate: 3.0000e-04
# Epoch 21/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9780 - loss: 0.0076 - val_accuracy: 0.9724 - val_loss: 0.0122 - learning_rate: 3.0000e-04
# Epoch 22/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9820 - loss: 0.0064 - val_accuracy: 0.9731 - val_loss: 0.0106 - learning_rate: 3.0000e-04
# Epoch 23/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9853 - loss: 0.0055 - val_accuracy: 0.9719 - val_loss: 0.0128 - learning_rate: 3.0000e-04
# Epoch 24/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 140ms/step - accuracy: 0.9869 - loss: 0.0049 - val_accuracy: 0.9740 - val_loss: 0.0114 - learning_rate: 3.0000e-04
# Epoch 25/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.9890 - loss: 0.0042 - val_accuracy: 0.9750 - val_loss: 0.0116 - learning_rate: 3.0000e-04
# Epoch 26/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.9893 - loss: 0.0039 - val_accuracy: 0.9731 - val_loss: 0.0129 - learning_rate: 3.0000e-04
# Epoch 27/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 140ms/step - accuracy: 0.9919 - loss: 0.0033 - val_accuracy: 0.9757 - val_loss: 0.0112 - learning_rate: 3.0000e-04
# Epoch 28/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9926 - loss: 0.0031 - val_accuracy: 0.9711 - val_loss: 0.0165 - learning_rate: 3.0000e-04
# Epoch 29/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9913 - loss: 0.0034
# Epoch 29: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9919 - loss: 0.0033 - val_accuracy: 0.9665 - val_loss: 0.0162 - learning_rate: 3.0000e-04
# Epoch 30/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.9941 - loss: 0.0024 - val_accuracy: 0.9753 - val_loss: 0.0134 - learning_rate: 9.0000e-05
# Epoch 31/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9938 - loss: 0.0025
# Epoch 31: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9939 - loss: 0.0024 - val_accuracy: 0.9753 - val_loss: 0.0150 - learning_rate: 9.0000e-05
# Epoch 32/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.9944 - loss: 0.0023 - val_accuracy: 0.9765 - val_loss: 0.0127 - learning_rate: 2.7000e-05
# Epoch 33/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9953 - loss: 0.0021 - val_accuracy: 0.9767 - val_loss: 0.0128 - learning_rate: 2.7000e-05
# Epoch 34/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9959 - loss: 0.0019 - val_accuracy: 0.9760 - val_loss: 0.0128 - learning_rate: 2.7000e-05
# Epoch 35/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9958 - loss: 0.0019
# Epoch 35: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9953 - loss: 0.0021 - val_accuracy: 0.9762 - val_loss: 0.0129 - learning_rate: 2.7000e-05
# Epoch 36/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9962 - loss: 0.0018 - val_accuracy: 0.9762 - val_loss: 0.0133 - learning_rate: 8.1000e-06
# Epoch 37/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9951 - loss: 0.0021
# Epoch 37: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9953 - loss: 0.0020 - val_accuracy: 0.9762 - val_loss: 0.0131 - learning_rate: 8.1000e-06
# Epoch 38/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9955 - loss: 0.0019 - val_accuracy: 0.9762 - val_loss: 0.0132 - learning_rate: 2.4300e-06
# Epoch 39/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9954 - loss: 0.0019
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9957 - loss: 0.0019 - val_accuracy: 0.9762 - val_loss: 0.0134 - learning_rate: 2.4300e-06
# Epoch 40/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9957 - loss: 0.0018 - val_accuracy: 0.9762 - val_loss: 0.0132 - learning_rate: 1.0000e-06
# Epoch 41/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9950 - loss: 0.0020 - val_accuracy: 0.9765 - val_loss: 0.0132 - learning_rate: 1.0000e-06
# Epoch 42/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 140ms/step - accuracy: 0.9958 - loss: 0.0018 - val_accuracy: 0.9762 - val_loss: 0.0131 - learning_rate: 1.0000e-06
# Epoch 43/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9953 - loss: 0.0019 - val_accuracy: 0.9762 - val_loss: 0.0134 - learning_rate: 1.0000e-06
# Epoch 44/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.9960 - loss: 0.0018 - val_accuracy: 0.9762 - val_loss: 0.0132 - learning_rate: 1.0000e-06
# Epoch 45/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.9949 - loss: 0.0019 - val_accuracy: 0.9762 - val_loss: 0.0132 - learning_rate: 1.0000e-06
# Epoch 46/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 140ms/step - accuracy: 0.9957 - loss: 0.0019 - val_accuracy: 0.9762 - val_loss: 0.0133 - learning_rate: 1.0000e-06
# Epoch 47/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.9957 - loss: 0.0019 - val_accuracy: 0.9762 - val_loss: 0.0133 - learning_rate: 1.0000e-06
# Epoch 48/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.9959 - loss: 0.0019 - val_accuracy: 0.9762 - val_loss: 0.0133 - learning_rate: 1.0000e-06
# Epoch 49/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 144s 140ms/step - accuracy: 0.9950 - loss: 0.0019 - val_accuracy: 0.9765 - val_loss: 0.0132 - learning_rate: 1.0000e-06
# Epoch 50/50
# 1028/1028 ━━━━━━━━━━━━━━━━━━━━ 143s 139ms/step - accuracy: 0.9948 - loss: 0.0020 - val_accuracy: 0.9762 - val_loss: 0.0133 - learning_rate: 1.0000e-06

# %%
gc.collect()
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
model.save('my_model_full.keras')
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9766 - loss: 0.0138
# Accuracy of the model is -  97.66480326652527 %

# %%
img = cv2.imread("music_dataset_spectro_full/train/dobro/222_spect.png")
img=cv2.resize(img,(img_size,img_size))
img= np.reshape(img,(-1, img_size, img_size, 3))
img=img/255

print(labels)
labels=np.array(labels)
pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# ['Accordion' 'Acoustic_Guitar' 'Banjo' 'Bass_Guitar' 'Clarinet' 'cowbell'
#  'Dobro' 'Drum_set' 'Electric_Guitar' 'flute' 'Harmonium' 'Horn'
#  'Keyboard' 'Mandolin' 'Organ' 'Piano' 'Saxophone' 'Shakers' 'Tambourine'
#  'Trombone' 'Trumpet' 'Ukulele' 'vibraphone' 'Violin']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# ['Dobro']
