# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow import keras
import warnings


warnings.filterwarnings('ignore')



model= keras.models.load_model("Classifiaction_model_full.keras")
img_size = 128
dataset = os.listdir("music_dataset_spectro_full_single/train") #use as labels
labels = dataset
print(labels)
# Out:
# ['Accordion', 'Acoustic_Guitar', 'Banjo', 'Bass_Guitar', 'Clarinet', 'cowbell', 'Dobro', 'Drum_set', 'Electric_Guitar', 'flute', 'Harmonium', 'Horn', 'Keyboard', 'Mandolin', 'Organ', 'Piano', 'Saxophone', 'Shakers', 'Tambourine', 'Trombone', 'Trumpet', 'Ukulele', 'vibraphone', 'Violin']

# %%
#Accordion test
img = cv2.imread("music_dataset_spectro_full_single/test/Accordion/2864_Accordion.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

labels=np.array(labels)
pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# ['Accordion']

# %%
#acoustic guitar test
img = cv2.imread("music_dataset_spectro_full_single/test/Acoustic_Guitar/2923_Acoustic_Guitar.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ['Acoustic_Guitar']

# %%
#Banjo test
img = cv2.imread("music_dataset_spectro_full_single/test/Banjo/2398_Banjo.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ['Banjo']

# %%
#Bass_Guitar test
img = cv2.imread("music_dataset_spectro_full_single/test/Bass_Guitar/2890_Bass_Guitar.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ['Bass_Guitar']

# %%
#Clarinet test
img = cv2.imread("music_dataset_spectro_full_single/test/Clarinet/507_Clarinet.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ['Clarinet']

# %%
#cowbell test
img = cv2.imread("music_dataset_spectro_full_single/test/cowbell/496_cowbell.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ['cowbell']

# %%
#Dobro test
img = cv2.imread("music_dataset_spectro_full_single/test/Dobro/389_Dobro.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ['Dobro']

# %%
#Drum_set test
img = cv2.imread("music_dataset_spectro_full_single/test/Drum_set/2918_Drum_set.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ['Drum_set']

# %%
#Electric_Guitar test
img = cv2.imread("music_dataset_spectro_full_single/test/Electric_Guitar/1052_Electric_Guitar.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ['Electric_Guitar']

# %%
#Flute test
img = cv2.imread("music_dataset_spectro_full_single/test/flute/2975_flute.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ['flute']

# %%
#Harmonium test
img = cv2.imread("music_dataset_spectro_full_single/test/Harmonium/1051_Harmonium.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ['Harmonium']

# %%
#Horn test
img = cv2.imread("music_dataset_spectro_full_single/test/Horn/1006_Horn.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ['Horn']

# %%
#Keyboard test
img = cv2.imread("music_dataset_spectro_full_single/test/Keyboard/1632_Keyboard.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ['Keyboard']

# %%
#Mandolin test
img = cv2.imread("music_dataset_spectro_full_single/test/Mandolin/1966_Mandolin.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ['Mandolin']

# %%
#Organ test
img = cv2.imread("music_dataset_spectro_full_single/test/Organ/1153_Organ.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ['Organ']

# %%
#Piano test
img = cv2.imread("music_dataset_spectro_full_single/test/Piano/460_Piano.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ['Piano']

# %%
#Saxophone test
img = cv2.imread("music_dataset_spectro_full_single/test/Saxophone/363_Saxophone.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ['Saxophone']

# %%
#Shakers test
img = cv2.imread("music_dataset_spectro_full_single/test/Shakers/1085_Shakers.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ['Shakers']

# %%
#Tambourine test
img = cv2.imread("music_dataset_spectro_full_single/test/Tambourine/446_Tambourine.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ['Tambourine']

# %%
#Trombone test
img = cv2.imread("music_dataset_spectro_full_single/test/Trombone/2372_Trombone.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ['Trombone']

# %%
#trumpet test
img = cv2.imread("music_dataset_spectro_full_single/test/Trumpet/402_Trumpet.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ['Trumpet']

# %%
#Ukulele test
img = cv2.imread("music_dataset_spectro_full_single/test/Ukulele/632_Ukulele.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ['Violin']

# %%
#Ukulele test
img = cv2.imread("music_dataset_spectro_full_single/test/Ukulele/633_Ukulele.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# ['Ukulele']

# %%
#vibraphone test
img = cv2.imread("music_dataset_spectro_full_single/test/vibraphone/404_vibraphone.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ['vibraphone']

# %%
#violin test
img = cv2.imread("music_dataset_spectro_full_single/test/Violin/504_Violin.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ['Violin']

# %%
# 32836 accordian, keyboard, trombone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32836_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[0.10788307 0.10451518 0.11009921 0.11871445 0.11535736 0.10704157
#   0.11414631 0.11222664 0.10938971 0.0998868  0.11971595 0.11380181
#   0.10690745 0.11081319 0.11617751 0.11518886 0.10616703 0.11323859
#   0.10798607 0.10394621 0.10581025 0.11693541 0.10379705 0.11782876]]
# [['Harmonium' 'Bass_Guitar' 'Violin' 'Ukulele' 'Organ' 'Clarinet' 'Piano'
#   'Dobro' 'Horn' 'Shakers' 'Drum_set' 'Mandolin' 'Banjo'
#   'Electric_Guitar' 'Tambourine' 'Accordion' 'cowbell' 'Keyboard'
#   'Saxophone' 'Trumpet' 'Acoustic_Guitar' 'Trombone' 'vibraphone' 'flute']]
# ['Harmonium' 'Bass_Guitar' 'Violin']

# %%
# 32837 Mandolin, trombone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32837_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top2 = [prediction2[0][0],prediction2[0][1]]

print(labels[prediction2])
print(labels[top2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[0.10190924 0.10420364 0.09638637 0.10355544 0.103051   0.10764092
#   0.09621647 0.09593487 0.1117372  0.11427105 0.09494843 0.10204199
#   0.10198261 0.11172242 0.10517831 0.09927174 0.10499217 0.09908698
#   0.099006   0.10950723 0.1026861  0.09811042 0.10731628 0.10571018]]
# [['flute' 'Electric_Guitar' 'Mandolin' 'Trombone' 'cowbell' 'vibraphone'
#   'Violin' 'Organ' 'Saxophone' 'Acoustic_Guitar' 'Bass_Guitar' 'Clarinet'
#   'Trumpet' 'Horn' 'Keyboard' 'Accordion' 'Piano' 'Shakers' 'Tambourine'
#   'Ukulele' 'Banjo' 'Dobro' 'Drum_set' 'Harmonium']]
# ['flute' 'Electric_Guitar']

# %%
# 32838 banjo, bass_guitar Piano

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32838_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[0.06307482 0.07879474 0.07751787 0.07991991 0.0809351  0.08154355
#   0.21964301 0.07098126 0.07887408 0.07382277 0.07165232 0.07590494
#   0.06366709 0.0869569  0.06482715 0.07418419 0.11096197 0.08188223
#   0.06123054 0.08225714 0.07816591 0.07009133 0.08828578 0.07585122]]
# [['Dobro' 'Saxophone' 'vibraphone' 'Mandolin' 'Trombone' 'Shakers'
#   'cowbell' 'Clarinet' 'Bass_Guitar' 'Electric_Guitar' 'Acoustic_Guitar'
#   'Trumpet' 'Banjo' 'Horn' 'Violin' 'Piano' 'flute' 'Harmonium'
#   'Drum_set' 'Ukulele' 'Organ' 'Keyboard' 'Accordion' 'Tambourine']]
# ['Dobro' 'Saxophone' 'vibraphone']

# %%
# 32839 keyboard, organ, Piano

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32839_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[0.09768372 0.07936455 0.10699034 0.08808459 0.09890289 0.0947251
#   0.09882793 0.10159688 0.08526474 0.11334758 0.10129541 0.09573824
#   0.09619306 0.08441681 0.10600317 0.12337286 0.1027402  0.07249274
#   0.13786682 0.09634106 0.12141795 0.09106337 0.1033766  0.10377328]]
# [['Tambourine' 'Piano' 'Trumpet' 'flute' 'Banjo' 'Organ' 'Violin'
#   'vibraphone' 'Saxophone' 'Drum_set' 'Harmonium' 'Clarinet' 'Dobro'
#   'Accordion' 'Trombone' 'Keyboard' 'Horn' 'cowbell' 'Ukulele'
#   'Bass_Guitar' 'Electric_Guitar' 'Mandolin' 'Acoustic_Guitar' 'Shakers']]
# ['Tambourine' 'Piano' 'Trumpet']

# %%
# 32840 acoustic guitar, banjo, violin

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32840_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[0.09000649 0.07332413 0.12840773 0.08372706 0.09189005 0.07350635
#   0.10548531 0.0910714  0.07709718 0.09156677 0.09459502 0.0970707
#   0.10186746 0.07007676 0.09420175 0.10923864 0.11495455 0.0728362
#   0.16139199 0.08570536 0.10026642 0.07987689 0.09393874 0.09322084]]
# [['Tambourine' 'Banjo' 'Saxophone' 'Piano' 'Dobro' 'Keyboard' 'Trumpet'
#   'Horn' 'Harmonium' 'Organ' 'vibraphone' 'Violin' 'Clarinet' 'flute'
#   'Drum_set' 'Accordion' 'Trombone' 'Bass_Guitar' 'Ukulele'
#   'Electric_Guitar' 'cowbell' 'Acoustic_Guitar' 'Shakers' 'Mandolin']]
# ['Tambourine' 'Banjo' 'Saxophone']

# %%
# 32841 acoustic guitar, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32841_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top2 = [prediction2[0][0],prediction2[0][1]]

print(labels[prediction2])
print(labels[top2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[0.10269389 0.09237844 0.09460822 0.10341249 0.10483858 0.10938016
#   0.10446164 0.10605401 0.10732748 0.12400535 0.11034896 0.11432428
#   0.09466434 0.10856162 0.11397713 0.11803684 0.09448912 0.09927373
#   0.10339513 0.10617988 0.11804894 0.0961576  0.11381166 0.10860753]]
# [['flute' 'Trumpet' 'Piano' 'Horn' 'Organ' 'vibraphone' 'Harmonium'
#   'cowbell' 'Violin' 'Mandolin' 'Electric_Guitar' 'Trombone' 'Drum_set'
#   'Clarinet' 'Dobro' 'Bass_Guitar' 'Tambourine' 'Accordion' 'Shakers'
#   'Ukulele' 'Keyboard' 'Banjo' 'Saxophone' 'Acoustic_Guitar']]
# ['flute' 'Trumpet']

# %%
# 32842 acoustic guitar, cowbell,horn

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32841_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[0.10269389 0.09237844 0.09460822 0.10341249 0.10483858 0.10938016
#   0.10446164 0.10605401 0.10732748 0.12400535 0.11034896 0.11432428
#   0.09466434 0.10856162 0.11397713 0.11803684 0.09448912 0.09927373
#   0.10339513 0.10617988 0.11804894 0.0961576  0.11381166 0.10860753]]
# [['flute' 'Trumpet' 'Piano' 'Horn' 'Organ' 'vibraphone' 'Harmonium'
#   'cowbell' 'Violin' 'Mandolin' 'Electric_Guitar' 'Trombone' 'Drum_set'
#   'Clarinet' 'Dobro' 'Bass_Guitar' 'Tambourine' 'Accordion' 'Shakers'
#   'Ukulele' 'Keyboard' 'Banjo' 'Saxophone' 'Acoustic_Guitar']]
# ['flute' 'Trumpet' 'Piano']

# %%
# 32843 drum_set, flute,shakers

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32843_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[0.03420715 0.03203227 0.06896395 0.04396148 0.11589956 0.04815967
#   0.0472672  0.03055281 0.01923109 0.3330726  0.01514895 0.02807552
#   0.02514458 0.02349215 0.03875702 0.03424025 0.02205956 0.02680412
#   0.02135172 0.0525432  0.03343456 0.04423706 0.04616952 0.02587118]]
# [['flute' 'Clarinet' 'Banjo' 'Trombone' 'cowbell' 'Dobro' 'vibraphone'
#   'Ukulele' 'Bass_Guitar' 'Organ' 'Piano' 'Accordion' 'Trumpet'
#   'Acoustic_Guitar' 'Drum_set' 'Horn' 'Shakers' 'Violin' 'Keyboard'
#   'Mandolin' 'Saxophone' 'Tambourine' 'Electric_Guitar' 'Harmonium']]
# ['flute' 'Clarinet' 'Banjo']

# %%
# 32845 acoustic guitar, dobro,trombone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32845_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [[0.10621919 0.09067771 0.08889071 0.10655386 0.10645764 0.11176676
#   0.09785239 0.0957725  0.11808972 0.10357168 0.10745507 0.09573147
#   0.10080278 0.10315476 0.11110966 0.11390118 0.09699831 0.09849253
#   0.09547679 0.09424478 0.12875785 0.11369021 0.1037911  0.1044533 ]]
# [['Trumpet' 'Electric_Guitar' 'Piano' 'Ukulele' 'cowbell' 'Organ'
#   'Harmonium' 'Bass_Guitar' 'Clarinet' 'Accordion' 'Violin' 'vibraphone'
#   'flute' 'Mandolin' 'Keyboard' 'Shakers' 'Dobro' 'Saxophone' 'Drum_set'
#   'Horn' 'Tambourine' 'Trombone' 'Acoustic_Guitar' 'Banjo']]
# ['Trumpet' 'Electric_Guitar' 'Piano']

# %%
# 32846 bass guitar, harmonium, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32846_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[0.10021409 0.09491167 0.10549217 0.1033811  0.10889728 0.10025346
#   0.11164911 0.10759071 0.10314373 0.10212266 0.1310866  0.10808849
#   0.10167608 0.10233885 0.11568985 0.12788072 0.11116928 0.10134223
#   0.10635043 0.09817079 0.10794079 0.09914396 0.10777415 0.11143713]]
# [['Harmonium' 'Piano' 'Organ' 'Dobro' 'Violin' 'Saxophone' 'Clarinet'
#   'Horn' 'Trumpet' 'vibraphone' 'Drum_set' 'Tambourine' 'Banjo'
#   'Bass_Guitar' 'Electric_Guitar' 'Mandolin' 'flute' 'Keyboard' 'Shakers'
#   'cowbell' 'Accordion' 'Ukulele' 'Trombone' 'Acoustic_Guitar']]
# ['Harmonium' 'Piano' 'Organ']

# %%
# 32849 tambourine, violin

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32849_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top2 = [prediction2[0][0],prediction2[0][1]]

print(labels[prediction2])
print(labels[top2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[0.10019414 0.10094698 0.11161466 0.11163165 0.11156986 0.10690232
#   0.11467744 0.10598771 0.09227479 0.10129393 0.09953686 0.11086429
#   0.10406807 0.11266127 0.10919819 0.09819332 0.10833279 0.10481025
#   0.1035077  0.10268077 0.09844762 0.09618272 0.10016551 0.11257616]]
# [['Dobro' 'Mandolin' 'Violin' 'Bass_Guitar' 'Banjo' 'Clarinet' 'Horn'
#   'Organ' 'Saxophone' 'cowbell' 'Drum_set' 'Shakers' 'Keyboard'
#   'Tambourine' 'Trombone' 'flute' 'Acoustic_Guitar' 'Accordion'
#   'vibraphone' 'Harmonium' 'Trumpet' 'Piano' 'Ukulele' 'Electric_Guitar']]
# ['Dobro' 'Mandolin']

# %%
# 32860 saxophone, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32860_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top2 = [prediction2[0][0],prediction2[0][1]]

print(labels[prediction2])
print(labels[top2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [[6.9027761e-04 5.0051276e-05 5.3422339e-04 9.9821055e-01 3.4298384e-04
#   1.9946097e-05 3.8414446e-04 3.7517637e-04 1.0644792e-03 9.6174308e-06
#   2.7751451e-04 7.1381754e-04 2.7826300e-06 1.8962658e-03 1.1252728e-05
#   1.5846870e-04 3.2515678e-04 4.4827140e-04 5.9474178e-04 1.2943248e-04
#   2.4409826e-04 1.2797560e-04 6.2608560e-05 8.9185514e-06]]
# [['Bass_Guitar' 'Mandolin' 'Electric_Guitar' 'Horn' 'Accordion'
#   'Tambourine' 'Banjo' 'Shakers' 'Dobro' 'Drum_set' 'Clarinet'
#   'Saxophone' 'Harmonium' 'Trumpet' 'Piano' 'Trombone' 'Ukulele'
#   'vibraphone' 'Acoustic_Guitar' 'cowbell' 'Organ' 'flute' 'Violin'
#   'Keyboard']]
# ['Bass_Guitar' 'Mandolin']

# %%
# 32872 eletric guitar, mandolin, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32872_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[0.11088563 0.09508143 0.09289796 0.10763392 0.10835496 0.11394688
#   0.09253636 0.10543479 0.11747166 0.10708798 0.10441574 0.09880073
#   0.10571656 0.12043186 0.10917768 0.11408522 0.10017995 0.09676734
#   0.09882786 0.10367757 0.1197158  0.11129746 0.10417809 0.10891993]]
# [['Mandolin' 'Trumpet' 'Electric_Guitar' 'Piano' 'cowbell' 'Ukulele'
#   'Accordion' 'Organ' 'Violin' 'Clarinet' 'Bass_Guitar' 'flute'
#   'Keyboard' 'Drum_set' 'Harmonium' 'vibraphone' 'Trombone' 'Saxophone'
#   'Tambourine' 'Horn' 'Shakers' 'Acoustic_Guitar' 'Banjo' 'Dobro']]
# ['Mandolin' 'Trumpet' 'Electric_Guitar']

# %%
# 32866 banjo, clarinet, violin

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32866_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[2.4923615e-03 3.1104228e-03 1.2723623e-03 1.7977050e-03 1.7308455e-03
#   1.2064311e-03 6.0127291e-04 1.5305600e-03 2.6529084e-03 2.5255268e-03
#   7.6944535e-03 2.4625759e-03 4.6133786e-03 5.3453207e-04 5.1146662e-03
#   1.1437126e-03 4.6508273e-04 6.3572153e-03 6.7338999e-03 2.7378714e-03
#   1.1671180e-03 7.3119090e-03 1.9543441e-03 9.8873895e-01]]
# [['Violin' 'Harmonium' 'Ukulele' 'Tambourine' 'Shakers' 'Organ'
#   'Keyboard' 'Acoustic_Guitar' 'Trombone' 'Electric_Guitar' 'flute'
#   'Accordion' 'Horn' 'vibraphone' 'Bass_Guitar' 'Clarinet' 'Drum_set'
#   'Banjo' 'cowbell' 'Trumpet' 'Piano' 'Dobro' 'Mandolin' 'Saxophone']]
# ['Violin' 'Harmonium' 'Ukulele']

# %%
# 32861 ukulele, cowbell, acoustic guitar
img = cv2.imread("Music_mixes_dataset_classification/test/mix/32861_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[0.09940847 0.08444063 0.08971988 0.1002119  0.08807248 0.10388631
#   0.13205907 0.09663435 0.09826519 0.09606233 0.11146543 0.10103668
#   0.09175897 0.08726873 0.10084774 0.09819278 0.0945169  0.10069364
#   0.09347405 0.0810146  0.10962909 0.09931942 0.10452528 0.1081663 ]]
# [['Dobro' 'Harmonium' 'Trumpet' 'Violin' 'vibraphone' 'cowbell' 'Horn'
#   'Organ' 'Shakers' 'Bass_Guitar' 'Accordion' 'Ukulele' 'Electric_Guitar'
#   'Piano' 'Drum_set' 'flute' 'Saxophone' 'Tambourine' 'Keyboard' 'Banjo'
#   'Clarinet' 'Mandolin' 'Acoustic_Guitar' 'Trombone']]
# ['Dobro' 'Harmonium' 'Trumpet']

# %%
# 32862 saxophone, trumpet,

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32862_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top2 = [prediction2[0][0],prediction2[0][1]]

print(labels[prediction2])
print(labels[top2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[0.11161134 0.10231186 0.1179523  0.12060315 0.11174655 0.10878467
#   0.1339361  0.11531958 0.11805972 0.10249996 0.12209016 0.11336832
#   0.10136799 0.09915809 0.11519209 0.10261637 0.1041928  0.11959021
#   0.10394612 0.09416614 0.11310615 0.11981475 0.10974792 0.129792  ]]
# [['Dobro' 'Violin' 'Harmonium' 'Bass_Guitar' 'Ukulele' 'Shakers'
#   'Electric_Guitar' 'Banjo' 'Drum_set' 'Organ' 'Horn' 'Trumpet'
#   'Clarinet' 'Accordion' 'vibraphone' 'cowbell' 'Saxophone' 'Tambourine'
#   'Piano' 'flute' 'Acoustic_Guitar' 'Keyboard' 'Mandolin' 'Trombone']]
# ['Dobro' 'Violin']
