# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow import keras
import warnings


warnings.filterwarnings('ignore')



model= keras.models.load_model("Classifiaction_model_single.keras")
img_size = 128
dataset = os.listdir("music_dataset_spectro_full_single/train") #use as labels
labels = dataset
print(labels)
# Out:
# ['Accordion', 'Acoustic_Guitar', 'Banjo', 'Bass_Guitar', 'Clarinet', 'cowbell', 'Dobro', 'Drum_set', 'Electric_Guitar', 'flute', 'Harmonium', 'Horn', 'Keyboard', 'Mandolin', 'Organ', 'Piano', 'Saxophone', 'Shakers', 'Tambourine', 'Trombone', 'Trumpet', 'Ukulele', 'vibraphone', 'Violin']

# %%
#Accordion test
img = cv2.imread("music_dataset_spectro_full_single/test/Accordion/2864_Accordion.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

labels=np.array(labels)
pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# ['Accordion']

# %%
#acoustic guitar test
img = cv2.imread("music_dataset_spectro_full_single/test/Acoustic_Guitar/2923_Acoustic_Guitar.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Acoustic_Guitar']

# %%
#Banjo test
img = cv2.imread("music_dataset_spectro_full_single/test/Banjo/2398_Banjo.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ['Banjo']

# %%
#Bass_Guitar test
img = cv2.imread("music_dataset_spectro_full_single/test/Bass_Guitar/2890_Bass_Guitar.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ['Bass_Guitar']

# %%
#Clarinet test
img = cv2.imread("music_dataset_spectro_full_single/test/Clarinet/507_Clarinet.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ['Clarinet']

# %%
#cowbell test
img = cv2.imread("music_dataset_spectro_full_single/test/cowbell/496_cowbell.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ['cowbell']

# %%
#Dobro test
img = cv2.imread("music_dataset_spectro_full_single/test/Dobro/389_Dobro.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Dobro']

# %%
#Drum_set test
img = cv2.imread("music_dataset_spectro_full_single/test/Drum_set/2918_Drum_set.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# ['Drum_set']

# %%
#Electric_Guitar test
img = cv2.imread("music_dataset_spectro_full_single/test/Electric_Guitar/1052_Electric_Guitar.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ['Electric_Guitar']

# %%
#Flute test
img = cv2.imread("music_dataset_spectro_full_single/test/flute/2975_flute.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ['flute']

# %%
#Harmonium test
img = cv2.imread("music_dataset_spectro_full_single/test/Harmonium/1051_Harmonium.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Harmonium']

# %%
#Horn test
img = cv2.imread("music_dataset_spectro_full_single/test/Horn/1006_Horn.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Horn']

# %%
#Keyboard test
img = cv2.imread("music_dataset_spectro_full_single/test/Keyboard/1632_Keyboard.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ['Keyboard']

# %%
#Mandolin test
img = cv2.imread("music_dataset_spectro_full_single/test/Mandolin/1966_Mandolin.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Mandolin']

# %%
#Organ test
img = cv2.imread("music_dataset_spectro_full_single/test/Organ/1153_Organ.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ['Organ']

# %%
#Piano test
img = cv2.imread("music_dataset_spectro_full_single/test/Piano/460_Piano.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# ['Piano']

# %%
#Saxophone test
img = cv2.imread("music_dataset_spectro_full_single/test/Saxophone/363_Saxophone.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Saxophone']

# %%
#Shakers test
img = cv2.imread("music_dataset_spectro_full_single/test/Shakers/1085_Shakers.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ['Shakers']

# %%
#Tambourine test
img = cv2.imread("music_dataset_spectro_full_single/test/Tambourine/446_Tambourine.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['Tambourine']

# %%
#Trombone test
img = cv2.imread("music_dataset_spectro_full_single/test/Trombone/2372_Trombone.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ['Trombone']

# %%
#trumpet test
img = cv2.imread("music_dataset_spectro_full_single/test/Trumpet/402_Trumpet.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ['Trumpet']

# %%
#Ukulele test
img = cv2.imread("music_dataset_spectro_full_single/test/Ukulele/632_Ukulele.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ['Ukulele']

# %%
#vibraphone test
img = cv2.imread("music_dataset_spectro_full_single/test/vibraphone/404_vibraphone.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255

pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ['vibraphone']

# %%
#violin test
img = cv2.imread("music_dataset_spectro_full_single/test/Violin/504_Violin.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
prediction = np.argmax(pred,1)
print(labels[prediction])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# ['Violin']

# %%
# 32836 accordian, keyboard, trombone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32836_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[4.4486737e-07 1.0787815e-08 2.5887945e-04 1.0105626e-12 1.7102426e-10
#   1.9082792e-08 5.0193199e-04 1.0893287e-08 6.6405693e-05 3.6333744e-10
#   9.6681436e-09 9.8272692e-13 9.7576594e-01 4.9928184e-07 6.6038075e-10
#   7.3845807e-10 4.2855509e-06 1.4404974e-07 2.1648227e-06 1.0303074e-06
#   3.9774000e-06 4.4970562e-05 2.0926311e-08 1.7793427e-08]]
# [['Keyboard' 'Dobro' 'Banjo' 'Electric_Guitar' 'Ukulele' 'Saxophone'
#   'Trumpet' 'Tambourine' 'Trombone' 'Mandolin' 'Accordion' 'Shakers'
#   'vibraphone' 'cowbell' 'Violin' 'Drum_set' 'Acoustic_Guitar'
#   'Harmonium' 'Piano' 'Organ' 'flute' 'Clarinet' 'Bass_Guitar' 'Horn']]
# ['Keyboard' 'Dobro' 'Banjo']

# %%
# 32837 Mandolin, trombone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32837_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[6.6039157e-01 5.2288616e-08 1.3309358e-05 1.8722628e-15 2.4890170e-08
#   1.8890558e-09 1.6328719e-09 3.7641130e-11 4.2677215e-07 7.9558576e-10
#   2.2676340e-01 1.6506228e-10 9.1792618e-09 1.0457809e-05 2.3606171e-11
#   1.7337934e-08 6.8331901e-05 1.9884528e-08 1.2302670e-08 2.0569591e-04
#   9.0011090e-06 7.1546005e-09 1.5504675e-08 6.3759802e-07]]
# [['Accordion' 'Harmonium' 'Trombone' 'Saxophone' 'Banjo' 'Mandolin'
#   'Trumpet' 'Violin' 'Electric_Guitar' 'Acoustic_Guitar' 'Clarinet'
#   'Shakers' 'Piano' 'vibraphone' 'Tambourine' 'Keyboard' 'Ukulele'
#   'cowbell' 'Dobro' 'flute' 'Horn' 'Drum_set' 'Organ' 'Bass_Guitar']]
# ['Accordion' 'Harmonium' 'Trombone']

# %%
# 32838 banjo, bass_guitar Piano

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32838_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[1.11653601e-12 1.94116065e-08 1.20709399e-06 9.77001818e-14
#   2.32411448e-13 5.98900271e-22 9.99813676e-01 3.40679464e-17
#   9.85695223e-08 2.85964915e-12 1.45923583e-18 1.58352710e-17
#   8.55706971e-14 7.84816257e-06 3.49150178e-15 5.09067066e-10
#   1.12865919e-05 4.74851032e-15 1.38242727e-12 1.29583248e-04
#   1.10408445e-11 3.10696157e-13 8.64104152e-07 2.81860513e-14]]
# [['Dobro' 'Trombone' 'Saxophone' 'Mandolin' 'Banjo' 'vibraphone'
#   'Electric_Guitar' 'Acoustic_Guitar' 'Piano' 'Trumpet' 'flute'
#   'Tambourine' 'Accordion' 'Ukulele' 'Clarinet' 'Bass_Guitar' 'Keyboard'
#   'Violin' 'Shakers' 'Organ' 'Drum_set' 'Horn' 'Harmonium' 'cowbell']]
# ['Dobro' 'Trombone' 'Saxophone']

# %%
# 32839 keyboard, organ, Piano

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32839_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[2.46261698e-18 3.19237850e-16 2.23248435e-13 4.72255972e-19
#   2.93872522e-16 5.81879000e-13 2.89710947e-22 1.89987869e-12
#   2.85239172e-13 3.39999892e-13 4.00119074e-17 1.88185267e-09
#   4.20047588e-19 3.01292724e-09 5.83245102e-19 2.36339414e-17
#   4.12352769e-13 4.54125946e-08 9.98773456e-01 9.89730609e-08
#   1.06773444e-10 7.35867750e-15 1.35803816e-06 8.27151837e-07]]
# [['Tambourine' 'vibraphone' 'Violin' 'Trombone' 'Shakers' 'Mandolin'
#   'Horn' 'Trumpet' 'Drum_set' 'cowbell' 'Saxophone' 'flute'
#   'Electric_Guitar' 'Banjo' 'Ukulele' 'Acoustic_Guitar' 'Clarinet'
#   'Harmonium' 'Piano' 'Accordion' 'Organ' 'Bass_Guitar' 'Keyboard'
#   'Dobro']]
# ['Tambourine' 'vibraphone' 'Violin']

# %%
# 32840 acoustic guitar, banjo, violin

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32840_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[8.9627807e-16 5.3236150e-17 9.9999994e-01 2.2518733e-18 9.2922331e-16
#   3.8248349e-14 9.9740088e-14 4.0233012e-20 2.2678216e-10 5.2943566e-15
#   5.6368175e-13 4.2411852e-24 2.5316483e-16 6.8072398e-10 4.2366959e-21
#   6.5993184e-16 3.0317122e-14 8.0121992e-11 2.2291950e-07 2.3965820e-13
#   1.4071036e-12 1.2864603e-14 2.3051705e-13 1.2191026e-10]]
# [['Banjo' 'Tambourine' 'Mandolin' 'Electric_Guitar' 'Violin' 'Shakers'
#   'Trumpet' 'Harmonium' 'Trombone' 'vibraphone' 'Dobro' 'cowbell'
#   'Saxophone' 'Ukulele' 'flute' 'Clarinet' 'Accordion' 'Piano' 'Keyboard'
#   'Acoustic_Guitar' 'Bass_Guitar' 'Drum_set' 'Organ' 'Horn']]
# ['Banjo' 'Tambourine' 'Mandolin']

# %%
# 32841 acoustic guitar, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32841_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[3.70522424e-19 1.31157536e-15 6.67988287e-09 2.28381940e-12
#   3.77268915e-14 1.22085887e-15 2.88856433e-17 4.33257830e-09
#   1.30376895e-06 3.77842993e-13 8.14716490e-18 9.12304967e-15
#   1.71169034e-11 1.24751351e-13 8.87858281e-18 4.81196506e-16
#   1.02961196e-16 9.07222638e-05 9.65643167e-01 9.03798412e-13
#   7.82075305e-13 8.68955297e-10 1.95808281e-09 9.21248104e-13]]
# [['Tambourine' 'Shakers' 'Electric_Guitar' 'Banjo' 'Drum_set'
#   'vibraphone' 'Ukulele' 'Keyboard' 'Bass_Guitar' 'Violin' 'Trombone'
#   'Trumpet' 'flute' 'Mandolin' 'Clarinet' 'Horn' 'Acoustic_Guitar'
#   'cowbell' 'Piano' 'Saxophone' 'Dobro' 'Organ' 'Harmonium' 'Accordion']]
# ['Tambourine' 'Shakers' 'Electric_Guitar']

# %%
# 32842 acoustic guitar, cowbell,horn

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32841_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[3.70522424e-19 1.31157536e-15 6.67988287e-09 2.28381940e-12
#   3.77268915e-14 1.22085887e-15 2.88856433e-17 4.33257830e-09
#   1.30376895e-06 3.77842993e-13 8.14716490e-18 9.12304967e-15
#   1.71169034e-11 1.24751351e-13 8.87858281e-18 4.81196506e-16
#   1.02961196e-16 9.07222638e-05 9.65643167e-01 9.03798412e-13
#   7.82075305e-13 8.68955297e-10 1.95808281e-09 9.21248104e-13]]
# [['Tambourine' 'Shakers' 'Electric_Guitar' 'Banjo' 'Drum_set'
#   'vibraphone' 'Ukulele' 'Keyboard' 'Bass_Guitar' 'Violin' 'Trombone'
#   'Trumpet' 'flute' 'Mandolin' 'Clarinet' 'Horn' 'Acoustic_Guitar'
#   'cowbell' 'Piano' 'Saxophone' 'Dobro' 'Organ' 'Harmonium' 'Accordion']]
# ['Tambourine' 'Shakers' 'Electric_Guitar']

# %%
# 32843 drum_set, flute,shakers

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32843_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[7.0498802e-15 4.9641351e-20 3.3034786e-09 4.4815994e-17 1.3669708e-05
#   4.0632859e-17 1.3071679e-18 5.1675160e-21 1.8711978e-16 9.9997497e-01
#   2.6103499e-15 7.9673544e-21 2.1359147e-17 5.9900142e-20 4.8281540e-20
#   4.3050342e-12 1.5127261e-16 1.2619785e-16 1.9527826e-13 1.7306844e-12
#   2.0151127e-17 5.7996969e-21 2.7826726e-13 2.3217006e-16]]
# [['flute' 'Clarinet' 'Banjo' 'Piano' 'Trombone' 'vibraphone' 'Tambourine'
#   'Accordion' 'Harmonium' 'Violin' 'Electric_Guitar' 'Saxophone'
#   'Shakers' 'Bass_Guitar' 'cowbell' 'Keyboard' 'Trumpet' 'Dobro'
#   'Mandolin' 'Acoustic_Guitar' 'Organ' 'Horn' 'Ukulele' 'Drum_set']]
# ['flute' 'Clarinet' 'Banjo']

# %%
# 32845 acoustic guitar, dobro,trombone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32845_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[4.5240007e-02 1.0818341e-10 1.5109693e-09 3.6907282e-16 8.5658307e-08
#   1.9924709e-10 5.6942966e-09 2.5276116e-11 4.9909719e-05 1.7844408e-12
#   1.2645369e-05 6.8407897e-11 1.8795372e-11 3.9714682e-04 4.3373479e-05
#   8.4397963e-14 2.4465754e-08 1.5604820e-10 2.5204673e-11 1.7177697e-08
#   6.8329465e-01 1.7907101e-09 1.6648122e-11 5.3041077e-08]]
# [['Trumpet' 'Accordion' 'Mandolin' 'Electric_Guitar' 'Organ' 'Harmonium'
#   'Clarinet' 'Violin' 'Saxophone' 'Trombone' 'Dobro' 'Ukulele' 'Banjo'
#   'cowbell' 'Shakers' 'Acoustic_Guitar' 'Horn' 'Drum_set' 'Tambourine'
#   'Keyboard' 'vibraphone' 'flute' 'Piano' 'Bass_Guitar']]
# ['Trumpet' 'Accordion' 'Mandolin']

# %%
# 32846 bass guitar, harmonium, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32846_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[3.2432514e-08 1.2483269e-18 2.1248543e-09 3.3266227e-23 2.5255839e-10
#   4.1698596e-09 2.0929239e-18 1.1022090e-16 8.8565197e-12 1.6252004e-13
#   9.9995703e-01 2.1340190e-15 3.5572684e-16 2.1069006e-08 3.5645069e-17
#   2.2941633e-15 9.3012602e-08 7.9998863e-12 2.7269972e-10 3.3249523e-09
#   2.1780022e-07 1.6993387e-15 1.7103444e-13 3.6641813e-07]]
# [['Harmonium' 'Violin' 'Trumpet' 'Saxophone' 'Accordion' 'Mandolin'
#   'cowbell' 'Trombone' 'Banjo' 'Tambourine' 'Clarinet' 'Electric_Guitar'
#   'Shakers' 'vibraphone' 'flute' 'Piano' 'Horn' 'Ukulele' 'Keyboard'
#   'Drum_set' 'Organ' 'Dobro' 'Acoustic_Guitar' 'Bass_Guitar']]
# ['Harmonium' 'Violin' 'Trumpet']

# %%
# 32849 tambourine, violin

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32849_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[5.0920393e-02 1.4333391e-06 5.4184018e-10 1.0664628e-13 1.2762486e-05
#   8.9003119e-12 2.0477732e-07 9.1662494e-12 7.9890462e-08 4.6061224e-10
#   5.7953343e-08 1.6084724e-07 5.8130354e-12 3.6669284e-05 1.8085825e-10
#   6.5672641e-11 9.4781047e-01 1.4019019e-11 3.4245079e-10 7.0530827e-05
#   1.7212538e-04 6.3143334e-06 1.0069514e-06 5.5868506e-05]]
# [['Saxophone' 'Accordion' 'Trumpet' 'Trombone' 'Violin' 'Mandolin'
#   'Clarinet' 'Ukulele' 'Acoustic_Guitar' 'vibraphone' 'Dobro' 'Horn'
#   'Electric_Guitar' 'Harmonium' 'Banjo' 'flute' 'Tambourine' 'Organ'
#   'Piano' 'Shakers' 'Drum_set' 'cowbell' 'Keyboard' 'Bass_Guitar']]
# ['Saxophone' 'Accordion' 'Trumpet']

# %%
# 32860 saxophone, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32860_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[8.43444746e-15 7.02488458e-12 1.05241454e-10 9.99918878e-01
#   4.12419231e-11 9.46605718e-20 8.92736145e-12 4.60091763e-13
#   4.30395721e-06 3.76754766e-14 7.13283930e-17 5.17154678e-14
#   2.13541055e-12 7.83735521e-10 1.17973409e-11 5.29418263e-12
#   3.37604304e-17 1.56511931e-07 1.81075865e-08 5.43637011e-15
#   2.70298402e-11 4.45062156e-08 3.63010620e-13 2.05133367e-16]]
# [['Bass_Guitar' 'Electric_Guitar' 'Shakers' 'Ukulele' 'Tambourine'
#   'Mandolin' 'Banjo' 'Clarinet' 'Trumpet' 'Organ' 'Dobro'
#   'Acoustic_Guitar' 'Piano' 'Keyboard' 'Drum_set' 'vibraphone' 'Horn'
#   'flute' 'Accordion' 'Trombone' 'Violin' 'Harmonium' 'Saxophone'
#   'cowbell']]
# ['Bass_Guitar' 'Electric_Guitar' 'Shakers']

# %%
# 32872 eletric guitar, mandolin, vibraphone

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32872_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[9.9993956e-01 3.3481072e-05 1.6279306e-09 2.5274921e-14 4.1164712e-09
#   3.4101175e-09 3.8391770e-09 4.7402605e-07 2.3063078e-05 9.0998192e-10
#   2.8446838e-08 3.4775633e-12 4.7943487e-08 3.6230783e-06 1.3377953e-08
#   3.4443805e-11 1.9965224e-10 1.6559520e-10 5.2609563e-11 1.2698059e-07
#   1.6160394e-08 4.6204171e-08 1.2970730e-09 9.4738777e-09]]
# [['Accordion' 'Acoustic_Guitar' 'Electric_Guitar' 'Mandolin' 'Drum_set'
#   'Trombone' 'Keyboard' 'Ukulele' 'Harmonium' 'Trumpet' 'Organ' 'Violin'
#   'Clarinet' 'Dobro' 'cowbell' 'Banjo' 'vibraphone' 'flute' 'Saxophone'
#   'Shakers' 'Tambourine' 'Piano' 'Horn' 'Bass_Guitar']]
# ['Accordion' 'Acoustic_Guitar' 'Electric_Guitar']

# %%
# 32866 banjo, clarinet, violin

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32866_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[4.40333577e-12 1.50849142e-11 4.07593013e-13 5.20555604e-12
#   5.39405814e-13 4.96060437e-09 1.34773615e-14 6.58429329e-08
#   1.16858530e-12 3.43722030e-11 1.18094488e-12 4.85645023e-06
#   2.10789960e-14 2.48810950e-09 9.18964141e-11 1.10384635e-15
#   5.95911224e-05 7.84588046e-03 3.53158605e-08 2.33122255e-09
#   1.05428344e-09 4.75335219e-06 7.90943652e-02 6.72482303e-04]]
# [['vibraphone' 'Shakers' 'Violin' 'Saxophone' 'Horn' 'Ukulele' 'Drum_set'
#   'Tambourine' 'cowbell' 'Mandolin' 'Trombone' 'Trumpet' 'Organ' 'flute'
#   'Acoustic_Guitar' 'Bass_Guitar' 'Accordion' 'Harmonium'
#   'Electric_Guitar' 'Clarinet' 'Banjo' 'Keyboard' 'Dobro' 'Piano']]
# ['vibraphone' 'Shakers' 'Violin']

# %%
# 32861 ukulele, cowbell, acoustic guitar
img = cv2.imread("Music_mixes_dataset_classification/test/mix/32861_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[9.9998289e-01 4.9745023e-13 8.0491905e-11 9.5285843e-21 6.6284968e-12
#   9.0918113e-16 5.8159544e-15 1.2993885e-16 1.7844979e-09 4.8617642e-16
#   2.6602021e-07 7.6672777e-13 8.1371378e-17 8.8753308e-07 2.0175981e-12
#   7.6894107e-12 2.8594809e-07 2.2380535e-12 2.7271805e-13 6.1066410e-09
#   5.0144340e-06 9.3831149e-13 1.7854875e-14 1.0975660e-09]]
# [['Accordion' 'Trumpet' 'Mandolin' 'Saxophone' 'Harmonium' 'Trombone'
#   'Electric_Guitar' 'Violin' 'Banjo' 'Piano' 'Clarinet' 'Shakers' 'Organ'
#   'Ukulele' 'Horn' 'Acoustic_Guitar' 'Tambourine' 'vibraphone' 'Dobro'
#   'cowbell' 'flute' 'Drum_set' 'Keyboard' 'Bass_Guitar']]
# ['Accordion' 'Trumpet' 'Mandolin']

# %%
# 32862 saxophone, trumpet,

img = cv2.imread("Music_mixes_dataset_classification/test/mix/32862_mix.png",0)
img=img[:img_size,:img_size]
img= np.reshape(img,(-1, img_size, img_size, 1))
img=img/255


pred=model.predict(img)
print(pred)
prediction1 = np.argsort(pred)
prediction2 = np.flip(prediction1)
top3 = [prediction2[0][0],prediction2[0][1],prediction2[0][2]]

print(labels[prediction2])
print(labels[top3])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[7.9442674e-19 1.9478961e-19 8.8141258e-11 2.0805933e-18 1.3426258e-17
#   1.1336549e-14 3.4192074e-14 5.0356176e-13 2.4948317e-18 1.0288943e-22
#   2.4639113e-20 7.0928464e-24 1.6638073e-17 1.0314435e-13 7.2453202e-20
#   4.7109257e-31 1.1518736e-19 3.6275351e-11 7.6065077e-13 1.8392198e-29
#   2.1235538e-09 1.0000000e+00 7.8748106e-19 3.0619984e-16]]
# [['Ukulele' 'Trumpet' 'Banjo' 'Shakers' 'Tambourine' 'Drum_set'
#   'Mandolin' 'Dobro' 'cowbell' 'Violin' 'Keyboard' 'Clarinet'
#   'Electric_Guitar' 'Bass_Guitar' 'Accordion' 'vibraphone'
#   'Acoustic_Guitar' 'Saxophone' 'Organ' 'Harmonium' 'flute' 'Horn'
#   'Trombone' 'Piano']]
# ['Ukulele' 'Trumpet' 'Banjo']
